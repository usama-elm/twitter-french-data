# %%
# !pip install nltk
# !pip install gensim
# Out:
# Collecting nltk
#   Downloading nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: click in /opt/conda/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.9/site-packages (from nltk) (4.63.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.9/site-packages (from nltk) (1.1.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.3.15-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (763 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.2/763.2 KB 2.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.7 regex-2022.3.15
# Collecting gensim
#   Downloading gensim-4.1.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.9/site-packages (from gensim) (1.21.5)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 KB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.18.1 in /opt/conda/lib/python3.9/site-packages (from gensim) (1.8.0)
# Installing collected packages: smart-open, gensim
# Successfully installed gensim-4.1.2 smart-open-5.2.1

# %%
import re
import string
import nltk
import pandas as pd
import gensim
import numpy as np

from gensim.models import Word2Vec
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.stem.snowball import FrenchStemmer

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("nlp").getOrCreate()

# %%
french_stopwords = stopwords.words('french')
french_stopwords.extend(["Replying to", "Replying", "to", 'replying'])
filtre_stopfr =  lambda text: [token for token in text if token.lower() not in french_stopwords]

def enlever_ponctuation(_str):
  _str = re.sub('['+string.punctuation+']', ' ', _str)
  _str = re.sub('[\r]', ' ', _str)
  _str = re.sub('[\n]', ' ', _str)
  _str = re.sub('[«"]', ' ', _str)
  return _str

def enlever_filler(str):
  return filtre_stopfr(word_tokenize(str))

def extraire_hashtags(str):
    hashtag_list = []
    for word in str.split():
        if word[0] == '#':
            hashtag_list.append(word[1:])
    return hashtag_list

def tokenization(_str):
    return enlever_filler(enlever_ponctuation(_str))

# %%
vaccins = pd.read_csv(r'vaccinsFull.csv')
print(vaccins)
# Out:
#       Unnamed: 0                            UserScreenName         UserName  \
# 0              0                         augustin barbeaux    @barbeauroch5
# 1              1                             Bayembi_borny    @BayembiBorny
# 2              2                           Merry Socialist  @Socialistesque
# 3              3                               incesticide  @apolitique2022
# 4              4                          Arkhos94 #vaccin        @arkhos94
# ...          ...                                       ...              ...
# 3487         257  Francki France N'OUBLIONS PAS LE DONBASS  @france_francki
# 3488         258                                   Lorenzo  @SaintExpedit78
# 3489         259                  JPB #TouchePasAuxEnfants        @jpb_ufic
# 3490         260                             Thierry henry       @grissom91
# 3491         261                                    Ⓥ 𝔐𝔞𝔫𝔲      @Emmanimals
#
#                      Timestamp  \
# 0     2022-01-01T21:34:54.000Z
# 1     2022-01-01T02:51:27.000Z
# 2     2022-01-01T22:44:14.000Z
# 3     2022-01-01T09:12:29.000Z
# 4     2022-01-01T19:50:17.000Z
# ...                        ...
# 3487  2022-04-08T17:50:27.000Z
# 3488  2022-04-08T09:17:12.000Z
# 3489  2022-04-08T16:32:53.000Z
# 3490  2022-04-08T11:08:53.000Z
# 3491  2022-04-08T18:44:50.000Z
#
#                                                    Text  \
# 0            augustin barbeaux\n@barbeauroch5\n·\n1 Jan
# 1                Bayembi_borny\n@BayembiBorny\n·\n1 Jan
# 2            Merry Socialist\n@Socialistesque\n·\n1 Jan
# 3                incesticide\n@apolitique2022\n·\n1 Jan
# 4                 Arkhos94 #vaccin\n@arkhos94\n·\n1 Jan
# ...                                                 ...
# 3487  Francki France N'OUBLIONS PAS LE DONBASS\n@fra...
# 3488                 Lorenzo\n@SaintExpedit78\n·\n8 Apr
# 3489        JPB #TouchePasAuxEnfants\n@jpb_ufic\n·\n20h
# 3490                Thierry henry\n@grissom91\n·\n8 Apr
# 3491                        Ⓥ 𝔐𝔞𝔫𝔲\n@Emmanimals\n·\n18h
#
#                                           Embedded_text Emojis  Comments  \
# 0     #vaccins #DictatureSanitaire #DictatureEnMarch...    NaN       NaN
# 1     ère bonne résolution de cette nouvelle année.....    NaN       NaN
# 2     Je pense que ⁦\n@NetflixFR\n⁩ et #CobraKai ont...  🌹 🌹 🐭       3.0
# 3     #voeuxmacron fake fake fake news!Sans l’Europe...    NaN       NaN
# 4     Un petit cadeau pour tout ceux qui croient les...  💉 💉 💉       2.0
# ...                                                 ...    ...       ...
# 3487  L’OMS rapporte des cas de perte d’audition apr...    NaN       NaN
# 3488  Momotchi interviewe Raphaël Berland, réalisate...    NaN       NaN
# 3489  Replying to \n@GaveEmmanuelle\n and \n@BFMTV\n...    NaN       NaN
# 3490  Replying to \n@XavierBazin2\nTu m'étonnes, les...      🏴       NaN
# 3491  #Vaccins: une plainte pour crime d’#empoisonne...      ☮       NaN
#
#      Likes Retweets                                         Image link  \
# 0      NaN        2  ['https://pbs.twimg.com/ext_tw_video_thumb/147...
# 1      NaN      NaN  ['https://pbs.twimg.com/ext_tw_video_thumb/147...
# 2      NaN      NaN  ['https://pbs.twimg.com/ext_tw_video_thumb/147...
# 3        1      NaN                                                 []
# 4        2        2  ['https://pbs.twimg.com/media/FICpEzWXIAkUD0j?...
# ...    ...      ...                                                ...
# 3487   NaN      NaN                                                 []
# 3488   NaN      NaN  ['https://pbs.twimg.com/card_img/1511595428806...
# 3489   NaN      NaN                                                 []
# 3490   NaN      NaN                                                 []
# 3491   NaN      NaN                                                 []
#
#                                               Tweet URL
# 0     https://twitter.com/barbeauroch5/status/147739...
# 1     https://twitter.com/BayembiBorny/status/147711...
# 2     https://twitter.com/Socialistesque/status/1477...
# 3     https://twitter.com/apolitique2022/status/1477...
# 4     https://twitter.com/arkhos94/status/1477366588...
# ...                                                 ...
# 3487  https://twitter.com/france_francki/status/1512...
# 3488  https://twitter.com/SaintExpedit78/status/1512...
# 3489  https://twitter.com/jpb_ufic/status/1512468533...
# 3490  https://twitter.com/grissom91/status/151238699...
# 3491  https://twitter.com/Emmanimals/status/15125017...
#
# [3492 rows x 12 columns]

# %%
hashtags=[]
mot_cles=[]
for _, row in vaccins.iterrows():
    hashtags.append(extraire_hashtags(row.Embedded_text))
    mot_cles.append(tokenization(row.Embedded_text))

# %%
vaccins = vaccins.assign(hashtags = hashtags)
vaccins = vaccins.assign(mot_cles = mot_cles)

# %%
# https://embeddings.net/embeddings/frWac_non_lem_no_postag_no_phrase_200_cbow_cut100.bin la source du modele Word2Vec
wv = gensim.models.KeyedVectors.load_word2vec_format('frWac_non_lem_no_postag_no_phrase_200_cbow_cut100.bin', binary=True)

# %%
wv.most_similar("père")
# Out:
# [('fils', 0.8278831243515015),
#  ('frère', 0.8005436658859253),
#  ('mère', 0.77669757604599),
#  ('grand-père', 0.7313958406448364),
#  ('aîné', 0.7286756038665771),
#  ('oncle', 0.7015424966812134),
#  ('adoptif', 0.6922641396522522),
#  ('beau-père', 0.6607111096382141),
#  ('paternel', 0.6535272598266602),
#  ('orphelin', 0.6337324976921082)]

# %%
def featureVecMethod(words, model):
    # Pre-initialising empty numpy array for speed
    num_features=model.vector_size
    featureVec = np.zeros(num_features,dtype="float32")
    nwords = 0
    #Converting Index2Word which is a list to a set for better speed in the execution.
    index2word_set = set(model.index_to_key)
    not_in_model = []
    for word in words:
        if word in index2word_set:
            nwords = nwords + 1
            v = model[word]
            #print(v)
            if np.isnan(v).any():
                print(word, v)
            featureVec = featureVec + model[word]
        else:
            not_in_model.append(word)
    #Here we can see if some of the words are not in the model, if so, we cannot use them for the clustering       
    print(not_in_model)
    # Dividing the result by number of words to get average
    if nwords != 0:
        featureVec = featureVec/nwords
    return featureVec
# Out:
# ['DictatureSanitaire', 'DictatureEnMarche', 'Député', 'Parlement', 'Big', 'Pharma', 'Quand', '2']
# array([ 0.04826047,  0.07433414, -0.11250746, -0.02080359,  0.05250414,
#        -0.07087479, -0.1988162 , -0.0129333 ,  0.08884215,  0.2574999 ,
#         0.12002086,  0.09143151,  0.09375057,  0.02924548, -0.03668779,
#         0.20636545, -0.26605338,  0.08967759,  0.06466752,  0.02635627,
#         0.12066436,  0.00485327, -0.29215553, -0.24607454,  0.46377438,
#         0.3324408 , -0.19971551,  0.17380495, -0.0120453 ,  0.10916305,
#        -0.07739734,  0.24886501, -0.3419363 , -0.07640602,  0.10175157,
#        -0.02358517, -0.20988277,  0.46855783, -0.09642693,  0.43309388,
#         0.00420387,  0.13834734,  0.19163741,  0.13250473, -0.23497827,
#        -0.36984587, -0.09696947,  0.5264313 ,  0.09964237, -0.03731539,
#         0.0195171 ,  0.16780172,  0.10646118,  0.29476306,  0.09516475,
#         0.01985354,  0.06143357, -0.22718485,  0.13759986, -0.04698601,
#         0.17967995,  0.05498347, -0.1541502 , -0.34252053, -0.10395689,
#         0.15924099,  0.03287253, -0.26859742,  0.25759804, -0.26654735,
#         0.05907469, -0.04714984, -0.27770287,  0.04912108, -0.02155996,
#         0.3196757 ,  0.01535091, -0.30973575, -0.27650872, -0.03551473,
#        -0.4331571 , -0.02435084,  0.20949192,  0.38367766,  0.00261928,
#        -0.02068336,  0.00936051, -0.46270192,  0.08872752, -0.23140447,
#         0.2284396 , -0.10979235,  0.20823349, -0.5123687 , -0.2074985 ,
#         0.22742963, -0.2737839 , -0.17048882, -0.02560826, -0.22815557,
#         0.27274433,  0.20143187,  0.15159853,  0.12778395,  0.03216559,
#         0.10808954, -0.34157225, -0.33381608, -0.19278707, -0.12091206,
#        -0.26198483, -0.47343826, -0.03825875, -0.1482407 ,  0.02656966,
#        -0.12423336,  0.33783326,  0.2287952 ,  0.03817726,  0.11562257,
#         0.08682643, -0.36804223, -0.574729  ,  0.28394794,  0.20842105,
#        -0.13005279, -0.12224523, -0.6434675 ,  0.23630634,  0.15598032,
#        -0.04733584,  0.26671243,  0.10424823, -0.03977196, -0.13049859,
#         0.06756987,  0.02088527, -0.14098832,  0.03906363, -0.0134753 ,
#        -0.04928468, -0.33956492, -0.3113681 , -0.4581113 , -0.09978099,
#        -0.15004483, -0.05948832,  0.113745  ,  0.03193883,  0.18714857,
#         0.1236061 , -0.23153642,  0.05783489, -0.17576748,  0.30022165,
#        -0.12220706,  0.32262295,  0.13603121,  0.23385654, -0.04634209,
#        -0.15197304, -0.21407312, -0.05033139, -0.11896855, -0.18466476,
#        -0.04464649, -0.10545482,  0.1374043 ,  0.11348609, -0.09413749,
#         0.388313  , -0.06047731,  0.12266497,  0.23065767, -0.10063698,
#        -0.097653  ,  0.14867477, -0.13448149,  0.15558825,  0.14054467,
#        -0.0136321 ,  0.01002563,  0.2914486 ,  0.12140442,  0.20843582,
#         0.32230124, -0.08300448,  0.04206152,  0.5046176 ,  0.03857381,
#        -0.01431383, -0.42091894, -0.13167126, -0.09553531,  0.04908597,
#         0.32855257,  0.18435012,  0.3841149 , -0.11505286,  0.15862891],
#       dtype=float32)

# %%
a = vaccins['mot_cles'][0]+vaccins['hashtags'][0]
# Out:
# ['vaccins',
#  'DictatureSanitaire',
#  'DictatureEnMarche',
#  'genocide',
#  'Député',
#  'roumain',
#  'Parlement',
#  'européen',
#  'expose',
#  'contrat',
#  'secret',
#  'Big',
#  'Pharma',
#  'Quand',
#  'gouvernement',
#  'sait',
#  'tout',
#  'tyrannie',
#  'quand',
#  'savez',
#  'tout',
#  'gouvernement',
#  'démocratie',
#  '2',
#  'vaccins',
#  'DictatureSanitaire',
#  'DictatureEnMarche',
#  'genocide']

# %%
valeurs_vectorisation_mots=[]
valeurs_vectorisation_hashtags=[]
valeurs_vectorisation=[]
for _, ligne in vaccins.iterrows():
    valeurs_vectorisation.append(featureVecMethod(ligne.mot_cles+ligne.hashtags, wv).tolist())
# Out:
# ['DictatureSanitaire', 'DictatureEnMarche', 'Député', 'Parlement', 'Big', 'Pharma', 'Quand', '2', 'DictatureSanitaire', 'DictatureEnMarche']
# ['Démonstration', 'Dr', 'Helene', 'Rossinot', 'Masque', 'gestesbarrieres', 'distanciationsociale', 'Masque', 'gestesbarrieres', 'distanciationsociale']
# ['\u2066', 'NetflixFR', '\u2069', 'CobraKai', 'Macron', 'Véran', 'VaccinObligatoire', '’', 'Vaccins', 'NonAuPasseVaccinal', '3', 'CobraKai', 'Véran)', 'Vaccins).', 'NonAuPasseVaccinal']
# ['voeuxmacron', 'Sans', '’', 'Europe', '’', 'covid19', 'NON', '’', '’', 'Europe', 'Mr', '’', 'voeux2022', 'presidentielle2022', 'cnews', 'OUI', '0', '04', '14', '1', 'voeuxmacron', 'covid19', 'voeux2022', 'presidentielle2022', 'cnews']
# ['Pfizer', 'Source', 'CETATE', '2', '2', '2', 'Pfizer,', 'moderna...']
# ['Annee2022', 'gouvernementFR', 'Macron', 'Castex', 'Blanquer', 'TV', 'État', 'CrimesAgainstHumanity', 'GIF', 'ALT', '1', '2', 'Annee2022', 'gouvernementFR', 'Macron', 'Castex', 'Blanquer', 'CrimesAgainstHumanity']
# ['Audition', 'Sénat', 'RatignierCarbonneil', 'ANSM', '2021', 'comptabilisons', '110000', '4', '45000', '5000', 'France', 'Bonne', 'LeLibrePenseur', 'LLP', 'Vrai', '1', 'Jan', 'Audition', 'Sénat', 'RatignierCarbonneil', 'ANSM', '2021', 'comptabilisons', '110000', '4', '45000', '5000', 'France', 'Bonne', '6', '6', 'RatignierCarbonneil,', 'vaccins.', 'RatignierCarbonneil,', 'vaccins.']
# ['wargonm', '2', 'Melenchon', 'Inénarrables', 'macronistes', '2', '6', 'Melenchon.']
# ['NonVaccinés', 'PasseVaccinal', 'Vaccins', 'Pourquoi', 'NonAuPassVaccinal', 'Randy', '5664', 'randy808', '29', 'Dec', '2021', 'The', 'VAERS', 'injuries', 'COVID19', 'JoeRogan', '983', '756', 'Adverse', 'Events', '108', '572', 'Hospitalizations', '107', '860', 'Urgent', 'Care', '12', '317', 'Bell', 'Palsy', '10', '429', 'Heart', 'Attacks', '20', '560', 'Myocarditis', '34', '615', 'Permanently', 'Disabled', '20', '622', 'Deaths', '100', 'Safe', 'And', 'Effective', '2', '1', '4', 'NonVaccinés,', 'PasseVaccinal', 'Vaccins', 'NonAuPassVaccinal', 'COVID19', 'JoeRogan']
# ['COVID19', 'FranceSoir', '1', 'Jan', 'BEST', 'OF', 'Dr', 'Michel', 'Lorgeril', 'francesoir', '258862', '4', '3', 'COVID19>', 'corruption>']
# ['Ardèche', 'Fareva', '50', '€', '3JcWblO', '1', '1', 'Ardèche', 'Fareva', 'vaccins.']
# ['Covid', '19', 'coronacircus', 'ElDictaTorOfficiel', 'El', 'Dic', 'TatoR', '1', 'Jan', 'Italie', 'Appel', '210', '92', 'Demande', 'Show', '1', '1', 'Covid_19', 'coronacircus']
# ['vaccinationCovid', 'Israël', '4emedose', 'immunodéprimées', 'Ça', 'Castex', 'Veran', 'immunodeprimees', 'AV', '202112310079', 'html…', 'BFMTV', 'Vaccination', 'Israël', 'immunodéprimées', '3', '2', 'vaccinationCovid', 'Israël', '4emedose', 'Castex', 'Veran']
# ['Archive', 'Crises', 'Cardiaques', 'debarjac1', 'effetssecondaires', 'PassVaccinalDeLaHonte', 'PasseVaccinal', '1', 'effetssecondaires', 'PassVaccinalDeLaHonte', 'PasseVaccinal']
# ['Vaccins', 'Sous', '’', 'francesoir', 'Jean', 'Marc', 'Sabatier', 'ENTRETIEN', '—', '’', 'Comment', '’', '’', '’', '’', '’', '1', '1', 'Vaccins']
# ['Ça', 'Pourquoi', 'Barbara78', 'dragonduclos', '28', 'Dec', '2021', 'Pr', 'Cyrille', 'Cohen', 'Après', '2', 'ARN', 'torpillées', '1', '1']
# ['3ème', 'DOSE', 'DOSE', 'TROP', 'Vaccin', 'Doublement', '’', '5c5d9302', '5fd1', '11ec', 'b88b', '611afda3f463…', 'ouestfrance', 'Doublement', '’', '15', '3', 'Vaccin']
# ['’', 'HydroxyChloroquine', '’', 'sociotechnique', 'Plus', 'MP', 'MERCI', '1', 'sociotechnique', 'vaccins.']
# ['Mandrinvienne', 'Brun01160147', '1jouroulautre', 'Ben', 'olivierveran', 'Résistants', 'Vaccins', 'Soviétisme', 'Psychiatrisation', '2', '4', 'Vaccins', 'Soviétisme', 'Psychiatrisation']
# ['Corinne', 'LALO', 'Vaccins', 'odysee', 'Citoicitoyen', '7SRwEJJk3xtJUTwbTrtauPgPkKAPbtZk…', 'LBRY', 'OdyseeTeam', 'odysee', 'Corinne', 'LALO', 'Vaccins', 'Corinne', 'LALO', 'Vaccins', 'Savoir', '1', 'Vaccins,', 'LBRY']
# ['5', 'GİZLİ', 'SERVİS', 'gizliservis06', '31', 'Dec', '2021', '2', 'doz', 'Sinovac', '2', 'doz', 'BioNTech', 'aşısı', 'yaptıranlar', 'için', '5', 'doz', 'randevuları', 'açıldı', '1', '2']
# ['18h', 'Macron', 'GAFAM', 'Microsoft', 'Facebook', 'Amazon', 'ThierryBreton', 'BillGates', 'Macron', 'GAFAM', 'Microsoft,', 'Facebook', 'Amazon,', 'ThierryBreton', 'BillGates']
# ['Vaccins', '’', 'francesoir', 'Jean', 'Marc', 'Sabatier', 'ENTRETIEN', '—', '’', 'Comment', '’', '’', '’', '’', '’', '2', 'Vaccins']
# ['Robert', 'Koch', 'Institut', 'Allemand', '4206', '4020', '95', '58', '1137', 'boostés', '186', 'Allemand']
# ['vtlau1', 'LCI', 'Ajouté', '11', 'pitchounes', 'BigPharma', 'Légiondhonneur', 'HydroxyChloroquine', 'Agnès', 'Buzyn', 'Ceux', 'LegionDHonneur', 'PassVaccinalDeLaHonte', '1', '3', 'BigPharma', 'Légiondhonneur', 'HydroxyChloroquine', 'LegionDHonneur', 'PassVaccinalDeLaHonte']
# ['Nüremberg', 'Dégoulinant', 'Nazisme', 'Alors', 'FÜHRERPRINZIP', 'Propagande', 'GOEBBELS', 'Mengele', 'ARBEIT', 'MACHT', 'FREI', 'commué', 'VAX', 'PASS', 'MACHT', 'FREI', 'Raphaël', 'Enthoven', 'Enthoven', 'R', '1', 'Jan', '’', '’', 'antivax', 'Show', 'FÜHRERPRINZIP', 'Propagande', 'GOEBBELS', 'Mengele']
# ['EChabriere', 'thoron', 'fyla', 'Traitements', 'icste', 'c19early', 'COVID', '19', '1', '618', 'COVID', '19', '1', '618', '3', '4', 'Traitements', 'imposture.']
# ['CommissaireEva', 'delphinebatho', 'antivax', 'ARN', 'Pharma', 'antivax']
# ['EmmanuelMacron', 'Pourquoi', '100', 'Français', 'svent', '1', '1', 'Où']
# ['’', '’', '’', 'OMS', 'Publie', 'BillGates', 'Rockfeller', '10665', '343361', 'WHO', '2019', 'nCoV', 'Digital', 'certificates', '2021', '1', '1', 'isAllowed', 'y…', '2', 'BillGates', 'Rockfeller']
# ['Vivre', 'Sainement', 'Bonne', 'qactus', '2022', '01', '01', 'Yka6ulmAnx', 'Twitter', 'Twitter', 'ShareButton', 'GetSocial…', 'getsocial']
# ['COVID19', 'Voici', '5', 'lacces', 'lenergie…', 'ODD7', 'HealthForAll', '1', '3', 'vaccins,', 'COVID19,', 'ODD7', 'HealthForAll']
# ['Pfizer', '’', '’', 'covid', '1', '3', 'covid']
# ['Samuel', 'Lafont', 'Buzyn', '07', '2017', '11x', '05', '2019', 'VincentLambert', 'Assassinat', '12', '2019', 'HydroxyChloroquine', '03', '2020', '04', '2020', 'Dénigrement', 'Raoult', '04', '2020', 'Rivrotril', 'EPAHD', '05', '2020', 'Exfiltration', 'Jean', 'Taxé', 'STOPtheSTEAL', 'jeanletaxe', '4', 'Apr', '2020', 'Narquin', 'JY', 'Buzyn', 'Vincent', 'Lambert', 'Etat', 'fakenews', '2013', 'Vincent', 'Lambert', '19', 'youtu', 'mqSMoCY6L7M', 'Buzyn:', 'VincentLambert', 'HydroxyChloroquine', 'Raoult', 'Rivrotril', 'STOPtheSTEAL', 'Buzyn', 'Lambert', 'fakenews', 'Lambert']
# ['DeFrance972', 'Français', 'crisesanitaire', 'Bonne', '2022', 'Français', 'crisesanitaire,', 'vaccins,']
# ['Enfantdabord2', 'Pr', 'Sabatier', 'FranceSoir', 'Sabatier', 'FranceSoir', 'vaccins,']
# ['denhass1', 'RFI', '10ans', '2021', '2022', 'PLUS', '10ans),donc', 'cobayes,et', 'enfants,', 'jeunes.', 'vérité.']
# ['nonVacccinés', 'nonVacccinés', 'vaccins.']
# ['CLemardele', '’', '1', '’', '’', '’', '1', '’']
# ['vtlau1', 'KarmaGirl', '73', 'Bref', 'PassVaccinalDeLaHonte', '4emedose', 'capiche', 'PassVaccinalDeLaHonte', '4emedose']
# ['Corsu63', 'Contois90050225', 'Macron2022', 'Quand', 'Macron', 'Zemmour2022', 'vaccins.', 'Zemmour2022']
# ['LCI', 'CNEWS', 'WHO', 'cnni', 'touteleurope', 'vonderleyen', 'SharghDaily', 'RFI', 'PrAlainFischer', 'APHP', 'laFHF', 'FMFofficiel', 'LePoint', 'lopinion', 'lesRepublicains', 'INT', 'Pourquoi', '2000', 'Chercheurs', 'Vaccins', 'Muselés', '500', 'Médecins', 'Accusent', 'JUSTICE', 'olivierveran', 'Vaccins']
# ['Mediavenir', 'Elysee', 'olivierveran', 'Macron', 'Véran', 'Macron', 'Véran']
# ['11pistache', 'COVID19France', 'BonneAnnee', 'LREM', 'PasseVaccinal', 'Macron20h', 'Figaro', '1477243661306015748', 'BcAsPt4zjIRJ1t7G0fyZow', '19…', 'Parmi', 'Légion', 'OMS', 'Santé', 'Agnès', 'Buzyn', 'Figaro', 'Figaro', '1', 'Jan', 'LegionDhonneur', '547', 'Agnès', 'Buzyn', 'Jean', 'François', 'Delfraissy', 'lefigaro', '547', 'distinguees', 'buzyn', 'delfraissy', '20220101', 'Social', 'echobox', 'Twitter', 'VWT16001', 'Echobox', '1641037308', '1…', '1', '1', 'COVID19France', 'BonneAnnee', 'LREM', 'PasseVaccinal', 'Macron20h', 'Santé', 'Buzyn.', 'LegionDhonneur']
# ['DoktorYak', 'evivyop', 'ADE', 'Facilitation', '’', '’', 'Spike', 'Étude', 'ShiZhengli', 'Molecular', 'Mechanism', 'Antibody', 'Dependent', 'Enhancement', 'Coronavirus', 'Entry', '10', '1128', 'jvi', '02015', '19…', 'ADE', 'Spike', 'ShiZhengli']
# ['faminifilm', 'ADE', '’', 'Spike', 'Étude', 'ShiZhengli', 'Mécanisme', '’', '10', '1128', 'jvi', '02015', '19…', '2', 'ADE', 'Spike', 'ShiZhengli']
# ['Danemark', '80', '99', 'Iles', 'Féroé', '82', '100', '4', '71', '143', 'Danemark']
# ['Israël', '4ème', 'Peut', '10ème', '9', '55', '110', 'Israël,', 'vaccins.']
# ['Corée', 'Sud', 'Manifestation', 'Séoul', 'Seoul', 'coreedusud', 'PassSanitaire', 'VaccinationObligatoire', '3', '16', '26', 'Seoul', 'coreedusud', 'PassSanitaire', 'VaccinationObligatoire']
# ['Pfizer', '’', 'Netflix', 'Pfizergate', 'Rappel', 'Vaccin', 'VaccinationObligatoire', 'mesuressanitaire', 'pierrotlezygo', 'Pfizergate', 'Rappel', 'Vaccin', 'VaccinationObligatoire', 'mesuressanitaire', 'pierrotlezygo']
# ['crowdbunker', 'Injections', 'Alexandra', 'Henrion', 'Caude', 'Injections', 'maloxxx8', 'wixsite', 'malonaturo', 'immunit', 'C3', 'A9', '1', '1', '2']
# ['EmmanuelMacron', 'EffetsSecondaires', 'Macron', 'Français', 'MacronDemission', 'passedelahonte', 'PasseVaccinal', 'PassSanitaireDeLaHonte', '1', 'EmmanuelMacron', 'EffetsSecondaires,', 'Macron', 'MacronDemission', 'passedelahonte', 'PasseVaccinal', 'PassSanitaireDeLaHonte']
# ['RogezVeronique', 'Quand', 'Omicron', 'Veran', 'Macron', 'PassVacinal', 'Vaccins', 'Europe', 'Quelle', 'Bcp', 'Mme', '4', '36', 'Omicron', 'Veran', 'Macron', 'PassVacinal', 'Vaccins']
# ['Dr', 'MichelDeLorgeril', 'Vaccins', 'FranceSoir', 'PassEM', 'VP', 'Zemmour2022', 'Cnews', 'LCI', 'BFMTV', '1', '1', 'MichelDeLorgeril,expert', 'Vaccins', 'PassEM&VP=non', 'Zemmour2022', 'Cnews', 'LCI', 'BFMTV']
# ['Juste', 'Dimitri', 'Jacques', 'DimitriJacques', '2', 'Jan', 'idrissaberkane', 'Allons', 'Show', '1', '45', '31', '1K', '2', '4', 'religion.']
# ['Demain', 'Liberté', 'Édition', '03', '2022', 'Sénat', 'Tebboune', 'HCA', 'Tamazight', 'APC', 'MJS', 'Covid19', 'Vaccins', 'Pain', 'Émigrés', 'Harraga', 'Algérie', '1', '4', '10', 'Liberté', 'Sénat', 'Tebboune', 'HCA', 'Tamazight', 'APC', 'MJS', 'Covid19', 'Vaccins', 'Pain', 'Émigrés', 'Harraga', 'Algérie']
# ['antivax', 'Veran', 'VeranEnPrison', 'Vaccin', 'PassVaccinal', 'PassVacinal', 'JDD', 'leJDD', '2', 'Jan', 'Santé', 'Olivier', 'Véran', 'JDD', 'antivax', 'lejdd', 'Politique', 'covid', '19', '4085600', 'Echobox', '1641076576', 'Social', 'xtor', 'CS1', '4', 'Twitter…', '1', 'vacciné,', 'Veran', 'VeranEnPrison', 'Vaccin', 'PassVaccinal', 'PassVacinal']
# ['Amsterdam', 'The', 'potentially', 'Change', 'View', '2', '5', 'Amsterdam:']
# ['noemiemln', 'Non', 'Allemagne', '70', 'Donc', '90', 'OMicron', '’', '’', '1', '1', 'OMicron,']
# ['110', '000', '4', '…', 'ANSM', 'EffetsSecondaires', 'LeLibrePenseur', 'LLP', 'Vrai', '1', 'Jan', 'Audition', 'Sénat', 'RatignierCarbonneil', 'ANSM', '2021', 'comptabilisons', '110000', '4', '45000', '5000', 'France', 'Bonne', '1', '1', '1', 'ANSM', 'EffetsSecondaires', 'RatignierCarbonneil,', 'vaccins.']
# ['Covid', '19', 'PassSanitaire', 'PasseVaccinal', 'PassDeLaHonte', 'Vaccin', 'VaccinationObligatoire', 'COVIDIOTS', 'Brusa', 'Carlo', 'Alberto', 'cab2626', '1', 'Jan', '’', '……………', 'Covid_19', 'PassSanitaire', 'PasseVaccinal', 'PassDeLaHonte', 'Vaccin', 'VaccinationObligatoire', 'COVIDIOTS']
# ['Effets', 'covid', '19', '’', 'Agence', 'groupegaullistesceaux', '2021', '12', '01', 'covid', '19', 'lagence', '…', 'GaullistesSceaux', 'EffetsSecondaires', 'groupegaullistesceaux', 'Effets', 'covid', '19', '’', 'Agence', 'Auditionnée', 'Sénat', 'Christelle', 'Ratignier', 'Carbonneil', '’', 'Agence', 'effet…', '1', '2', 'EffetsSecondaires']
# ['Dr', 'Peter', 'McCullough', 'C19', 'olivierveran', 'COVID19', 'theepochtimes', 'Dr', 'Peter', 'McCullough', 'Vaccine', 'Mandates', 'Should', 'Be', 'Repealed', 'COVID', '19', 'mandates', 'repealed', '1', '1', '1', 'COVID19']
# ['3', '4', 'Surtout', 'COVID19', 'Nicolas', 'Berrod', 'nicolasberrod', '2', 'Jan', 'A', '15', '4', '7', 'O', 'Véran', 'JDD', 'lejdd', 'Politique', 'covid', '19', '4085600', 'Echobox', '1641076319', 'Social', 'xtor', 'CS1', '4', 'Twitter…', 'Show', '1', '1', 'COVID19']
# ['PCR', 'dysfonctionnent', '1', 'vacciné,']
# ['DREES', 'Décembre', '63', 'Covid', 'Vaccins', 'COVID19', 'Vaccins', 'COVID19']
# ['BFMTV', 'Patrick', 'Pelloux', 'virologue', 'PrimumNonNocere', 'NonALaVaccinationObligatoire', 'NonAuPassVaccinal', 'François', 'LeConfinéMasqué', 'ConfineMasque', '30', 'Dec', '2021', 'Virologue', 'Expert', 'Vaccins', 'Geert', 'Vanden', 'Bossche', 'Covid19', 'youtu', '1W18i4gM', '98…', 'NonAuPassVaccinal', 'nonvaccines', 'Show', '2', '5', 'virologue', 'vaccins,', 'PrimumNonNocere', 'NonALaVaccinationObligatoire', 'NonAuPassVaccinal', 'Virologue', 'Vaccins', 'Covid19', 'NonAuPassVaccinal', 'nonvaccines']
# ['Patchez', 'Patchez', 'Patchez', '’', '’', 'Vaccin', 'PassVacinal', 'PasseVaccinal', 'tdgGeneve', '2', 'Jan', 'Lutte', 'Covid', '19', 'dlvr', 'SGP02D', '1', 'Vaccin', 'PassVacinal', 'PasseVaccinal']
# ['SP95', 'SP95', 'E10', 'SP98', 'E85', 'GPL', 'PassVaccinal', 'PassVacinal', 'patrickpelloux', 'BFMTV', 'BFMTV', '2', 'Jan', 'Patrick', 'Pelloux', 'Covid', '19', '1', 'vaccin,', 'PassVaccinal', 'PassVacinal', 'patrickpelloux']
# ['Pdg', 'Moderna', 'Mise', 'COVID19France', 'covid', 'Moderna', 'MacronDestitution', 'VeranDemission', 'Pierre', 'Jean', 'Bonnat', 'PJBonnat', '31', 'Dec', '2021', 'PDG', 'Moderna', '’', '’', 'Ça', '1', '1', 'COVID19France', 'covid', 'Moderna', 'MacronDestitution', 'VeranDemission']
# ['Bravo', 'tonynetto', 'followers', 'Attendons', 'Covid', 'tonynetto', 'tonynetto10', '2', 'Jan', 'Lancet', '89', 'UK', 'COVID', 'vaxxed', 'Principia', 'Scientific', 'Intl', 'covid', '\u2066', 'EmmanuelMacron\u2069', '\u2066', 'olivierveran\u2069', '89', 'covid', 'vaxxed', '…', 'Covid', 'covid']
# ['36', '627', 'COVID19', 'Europe', 'Pandemie', 'CourrierDesStratèges', 'CStrateges', '2', 'Jan', 'chiffres…', '1', 'COVID19,', 'Pandemie']
# ['Quand', '’', '’', 'EffetsSecondaires', 'TroublesCognitifs', 'Bizarre', 'neurological', 'illness', 'plagues', 'Canadians', '—', 'RT', 'World', 'News', 'Dozens', 'preexisting', 'symptoms', 'activists', 'EffetsSecondaires', 'TroublesCognitifs']
# ['Quand', 'Président', 'civisme…Petit', 'Etats', 'vaccinale…À', 'VD', 'nenuphar', '42', '2', 'Jan', 'ITALIE', 'DÉCÈS', 'CONFIRMÉ', 'VACCIN', 'APPEL', '210', '92', 'VOICI', 'REPONSE', 'MINISTERE', 'Marcello', 'Pamio', '1er', '2022', 'covid', '1', '3', 'Show', 'vaccins#']
# ['Excellent', 'Ici', 'Jean', 'Jacques', 'Ohana', 'jjohana', '1', 'Jan', 'Covid', '’', '’', '’', '1', 'Show', '1', 'vaccins.']
# ['BigPharma', 'ARNm', 'Enfants', '’', 'Vaccins', 'Urgence', 'Enfants', 'R', 'KennedyJr', 'PassEM', 'VP', 'Zemmour2022', 'Cnews', 'LCI', 'BFMTV', 'ARNm', 'Enfants', 'Vaccins', 'Enfants»', 'PassEM&VP=non', 'Zemmour2022', 'Cnews', 'LCI', 'BFMTV']
# ['Megarbane', 'Quand', 'indemniseront', 'Megarbane', 'vaccins,', 'vacciner.']
# ['CNEWS', 'Danemark', '80', '99', 'Iles', 'Féroé', '82', '100', '1', 'Danemark']
# ['David', 'Pujadas', 'Omicron', 'lemediaen442', 'sattaque', 'lappui', 'fbclid', 'IwAR2448xn9ZuyFBl2llw7T7Ij9Dz', 'UNov1oo6KI78xUyrm2dSpqZDl6okroM…', 'CORONAVIRUS', 'VACCINS', 'OUTILS', 'ETATS', 'VAGUES', 'MENSONGES', 'STOP', 'lemediaen442', 'David', 'Pujadas', 'Omicron', 'LCI', 'Omicron', 'CORONAVIRUS', 'VACCINS', 'OUTILS', 'ETATS', 'VAGUES', 'MENSONGES', 'STOP']
# ['Quoi', 'Grimaldi', 'Grimaldi,']
# ['Patriotes', '’', '’', 'France', '’', 'Flynn', 'trumpisme', 'France', '’', 'Trump', 'ARNm', 'Zulu', 'Zulu18360299', '2', 'Jan', 'Après', 'Trump', 'Macron', 'Pen', 'lepenjm', 'status…', 'Patriotes', 'France', 'Trump', 'ARNm']
# ['Dr', '8', '19', '48', '1', 'VaccinationObligatoire', 'Vaccin', 'Cat', '†', 'Catharsis777', '2', 'Jan', 'DR', 'SHERRI', 'TENPENNY', 'VACINS', 'MACHINES', 'TUER', 'PARFAITEMENT', 'CONÇUES', 'vgxxh3', 'sherri', 'tenpenny', 'vacins', 'html…', 'VaccinationObligatoire', 'Vaccin']
# ['Canada', 'IT', 'IS', 'NOT', 'COVID19', 'Canada', 'COVID19', 'IT', 'IS', 'Prime', 'Minister', 'Justin', 'Trudeau', 'Justin', 'Trudeau', 'westernstandardonline', '2021', '12', 'unvaccinated', 'racist', 'misogynistic', 'extremists', '…', 'Canada', 'JustinTrudeau', 'Vaccines', 'Racist', 'COVID19', 'westernstandardonline', 'Trudeau', 'unvaccinated', 'racist', 'misogynistic', 'extremists', 'But', 'Quebec', 'questioned', 'whether', 'Canada', 'Canada', 'JustinTrudeau', 'Vaccines', 'Racist', 'COVID19']
# ['manu1er', 'JMLP', 'Patriotes', '90', 'abusdefaiblesse', 'StopDictatureSanitaire', 'covid', 'StopHysterieSanitaire', 'Jean', 'Marie', 'Pen', 'lepenjm', '2', 'Jan', 'Covid', '19', 'Amitiés', 'manu1er', 'Patriotes', 'abusdefaiblesse', 'StopDictatureSanitaire', 'covid', 'StopHysterieSanitaire', 'Covid_19']
# ['’', '’', 'ARNm', 'StopHysterieSanitaire', 'StopHysterieVaccinale', 'Resistance', 'NonAuPassVaccinal', 'nonauPasseVaccinal', 'COVID', 'covidvariant', 'lesakerfrancophone', 'dautopsie', 'irrefutables', 'darnm', 'vaccination…', 'StopHysterieSanitaire', 'StopHysterieVaccinale', 'Resistance', 'NonAuPassVaccinal', 'nonauPasseVaccinal', 'COVID', 'covidvariant']
# ['Cequi', '’', 'TV', 'Libertés', 'tvlofficiel', '2', 'Jan', 'Covid', '19', '3e', '3', '4', '3', '7', 'Olivier', 'Véran', 'JDD', 'tvlibertes', 'covid', '19', '3e', '3', '4', '3', '7', 'jdd…', 'Covid-19', 'Véran']
# ['covid', 'antivax', 'rienfaire', 'jemenfout', 'vstreamcomplet', '6462', 'dni', 'html…', 'covid', 'antivax', 'rienfaire', 'jemenfout']
# ['antivaxx', 'Être', 'Pourquoi', 'Enthoven', 'R', 'Procureur', 'RésistantCloversForAssange', 'CarrPatrick2', '2', 'Jan', 'enthovenestuncon', 'Enthoven', 'R', 'sta…', '1', '1', 'antivaxx', 'enthovenestuncon']
# ['Etresouverain', 'Kla', 'TV', 'Dommages', 'Covid', 'Nouveau', 'Ivo', 'Sasek', 'odysee', 'etresouverain', '2022', '01', '01', 'DommagesCausesParLesVaccinsCov', 'klaTV', '1', '7SRwEJJk3xtJUTwbTrtauPgPkKAPbtZk…', 'LBRY', 'OdyseeTeam', 'odysee', 'Etresouverain', 'Kla', 'TV', 'Dommages', 'Kla', 'TV', 'Kla', 'TV', 'Ivo', 'Sasek', 'X', 'Suisse', 'LBRY']
# ['COVID19', 'Rappel', 'OMS', 'PROGRAMMES', 'RAPPEL', 'SANS', 'DISCERNEMENT', 'TOUTES', 'CHANCES', 'PROLONGER', 'PANDÉMIE', 'PLUTÔT', 'METTRE', 'FIN', 'Aucun', 'OMS', 'illusionselon', 'Cov', '1', '2', 'COVID19>']
# ['youtu', 'STPopTOrPVE', 'LesGuignols', 'Léger', 'Guignols', 'CANAL', 'GÉNÉRATION', 'GUIGNOLS', '’', '’', 'Johnny', 'Hallyday', 'Jacques', 'Chirac', '1', '2', 'vaccins...']
# ['COVID19', 'Lettre', 'lesakerfrancophone', 'lordre', 'medecins…', '2', '2', 'COVID19>']
# ['lepenjm', 'Attention', 'jeanmarie', 'Wuhan', '1', '1', '5', 'jeanmarie,', 'Wuhan;']
# ['hyperfraise', 'Toutes', 'Vaccin', 'lanouvellerepublique', 'Vaccin', '90', '’', 'Depuis', 'Covid', '19', '’', '90', 'Comment', '1', 'Vaccin']
# ['LCI', 'nanamiemarie', 'Télétoubibs', 'Alors', '’', '’', '’', '’', 'EXCUSÉ', 'PLUS', '2', 'vaccins.']
# ['JeanLeonetti', 'davidlisnard', 'Désolé', 'Covid', 'Voir', 'JulieLeGalliard', 'BigPharma', 'France', 'Julie', 'Galliard', 'Covid', '19', 'Hospitalisée', 'Julie', 'Galliard', '1', 'Covid.', 'JulieLeGalliard,', 'BigPharma']
# ['Commission', 'Comme', 'Europe', 'Disclose', 'disclosetv', '2', 'Jan', 'NOW', 'People', 'mauled', 'beaten', 'unauthorized', 'Covid', 'Amsterdam', 'Show', 'Amsterdam.']
# ['qualitif', '1']
# ['Mediavenir', 'chuteront', 'Covid', '19', 'COVID19', 'PCR', 'PassSanitaire', 'Pfizer', 'Covid_19', 'COVID19', 'PCR', 'PassSanitaire', 'Pfizer']
# ['CerfiaFR', 'Tests', 'bigpharma', 'infectiologue', '’', '’', 'francesoir', 'Stéphane', 'Gayet', 'ARNm', 'Médecin', 'infectiologue', 'Stéphane', 'Gayet', 'Entretien', '1', '1', 'bigpharma']
# ['BFMTV', 'francesoir', '3…', 'Stop', 'francesoir', 'Jean', 'Marc', 'Sabatier', 'ENTRETIEN', '—', '’', 'Comment', '’', '’', '’', '’', '’', 'fascisme.']
# ['Lau', 'Be1', 'Enthoven', 'R', '’', 'ARN', 'Covid', '19', '’', 'FDA', '1', 'Covid_19']
# ['leJDD', 'bigpharma', 'assumaient', '3', 'bigmedia', 'assumaient', 'confinements', 'bigpharma,', 'macron,', 'veran,', 'bigmedia']
# ['JeanMarie', 'ARNm', 'Marine', '2020', 'Dire', 'politicars', 'JeanMarie', 'Marine']
# ['nicolasberrod', 'Toutes', 'microbeCOVID19', '3', 'microbeCOVID19']
# ['FCOUILBAULT1', '’', 'bonneannee2022', 'COVID19', 'MontchalinGate', 'Pfizergate', 'conseildedefense', 'bonneannee2022', 'COVID19', 'MontchalinGate', 'Pfizergate', 'conseildedefense']
# ['France2tv', 'Vaccins', '’', 'Tiens', '’', '20hweekend', 'Covid', '19', 'Vaccins', '20hweekend', 'Covid_19']
# ['DesaintLaurent1', '3', '10', 'masques,']
# ['11', 'Vaccin', 'Vaccination', 'effetsindesirables', 'Combien', 'Invalides', 'VaccinationObligatoire', 'France', 'RaderSerge', 'TouchePasAuxEnfants', 'touchepasamesenfants', 'Macron2022', 'Pecresse', 'Vaccin', 'Vaccination', 'effetsindesirables', 'VaccinationObligatoire', 'France', 'TouchePasAuxEnfants', 'touchepasamesenfants', 'Macron2022', 'Pecresse']
# ['Enthoven', 'R', 'Camarade', '’', 'aphaque', 'antivax', 'E', 'Borne', 'ROI', 'ARNm', 'ARNm']
# ['100', 'ANSM', 'BigPharma', '50', 'AssoCovid', 'BigPharma']
# ['AubBoq', 'France', 'Christian', 'Vélot', 'PDF', 'CRIIGEN', 'ARNm', 'Vaccins', 'criigen', 'uploads', '2021', '03', '2021', '02', '24', 'Reponses', 'Globales', 'Grand', 'Public', '04', 'pdf…', 'PDF', 'CRIIGEN', 'ARNm', 'Vaccins']
# ['lestrepublicain', 'Si', 'bêler', 'Veran', 'Castex', 'COVID19', 'Omicron', '’', 'xenothera', 'xav19', '1', '2', 'Veran', 'Castex', 'COVID19', 'Omicron', 'xav19']
# ['vtlau1', 'SylasMondesir', '2', 'Ca', 'nonvaccines', 'EffetsSecondaires', 'effetsindesirables', 'nonvaccines', 'EffetsSecondaires', 'effetsindesirables']
# ['COVID19France', 'COVID19fr', 'Vaccin', '’', '3ème', 'Pfizer', '7', '50', '64', 'COVID19France', 'COVID19fr', 'Vaccin', 'Pfizer']
# ['Professeur', 'Claverie', '’', '’', 'périmer', '’', '’', 'Covid', '19', 'Omicron', 'PassVacinal', 'Covid', '15', '17', 'vaccin,', 'Covid_19', 'Omicron', 'PassVacinal', 'Covid']
# ['Presidentielle2022', 'Histoire', 'Fabien', 'Roussel', 'LeDéfiDesJoursHeureux', 'Roussel2022', '2', '20', '36', 'Presidentielle2022', 'LeDéfiDesJoursHeureux', 'Roussel2022']
# ['PasseVaccinal', 'Si', 'Covid', '19', 'Omicron', 'réas', 'STOP', 'Vaccins', 'PasseVaccinal', 'Passesanitaire', 'Cap', 'medicalfollower', '3', 'Jan', 'Pr', 'Claverie', 'virologue', '3', '4', 'PasseVaccinal', 'Covid-19', 'Omicron', 'Vaccins', 'PasseVaccinal', 'Passesanitaire']
# ['France', 'COVID19', 'Covid19Fr', 'COVID19France', 'Vaccin', 'Covid', 'Septuagénaires', '4', '6', 'France', 'COVID19', 'Covid19Fr', 'COVID19France', 'Vaccin']
# ['agnesbuzyn', '11', '4', '3', 'agnesbuzyn']
# ['Jaime', 'Horta', 'JaimeHorta17', '3', 'Jan', 'Brésil', 'nsctotal', 'catarinense', 'campea', 'brasileira', 'morre', 'vitima', 'infarto', '32', 'anos…', 'Guaramirim', '32', 'Monique', 'Piske', '1', '2']
# ['Témoignage', 'Vaud', '03', '01', '22', '1', '3', 'COVID19', 'Vaccin', 'Chaîne', 'YouTube', 'Sabrina', 'youtu', 'zC9EI', '9rzI', '2', '18', '53', '1', '3', '3', 'COVID19', 'Vaccin']
# ['TOTALEMENT', 'INEFFICACES', 'Omicron', '’', '’', 'Preuve', 'Danemark', 'Omicron', '8', '5', '91', '5', 'Dont', '17', '7', '4', 'Omicron']
# ['1', '3', '15', 'coroners', 'Vaccination', '14', '15', '93', 'Vaccins', '2', '10', '8', 'Vaccination', 'Vaccins']
# ['RT', 'BFMTV', 'Jean', 'Luc', 'Mélenchon', 'From', 'BFMTV', '2', '2', 'Mélenchon,', 'masques,', 'vaccins,']
# ['GVT', 'Australien', 'Vaccins', 'Pfizer', 'Moderna', '4ème', '5ème', 'StopGenocide', '1', '1', 'Vaccins', 'Pfizer', 'Moderna', 'StopGenocide']
# ['Netflix', 'NatureBeauty', 'Contre', 'COVID19', 'VaccinezVous', '1', 'Netflix,', 'NatureBeauty.', 'COVID19,', 'VaccinezVous']
# ['COVID19', 'PassSanitaire', 'PassVaccinal', 'Excellente', 'Merci', 'MartineWonner', 'LCP', 'LCP', '3', 'Jan', 'MartineWonner', 'Covid', 'DirectAN', '9', '12', 'COVID19>', 'PassSanitaire>', 'PassVaccinal>', 'Covid', 'DirectAN']
# ['A', 'Absolument', 'Bogdanoff', 'Raoult', 'Pfizer', 'Moderna', 'COVID19', 'SophiaAram', '3', 'Jan', 'Covid', 'Didier', 'Raout', 'Dernière', 'Bogdanoff', 'francebleu', 'cavousf5', 'statu…', '2', '1', 'Bogdanoff', 'Raoult', 'Pfizer', 'Moderna', 'COVID19']
# ['virologue', '1', '3', '8', '#vaccins']
# ['Ça', '3', 'X', 'Covid', '19', 'VaccinezVous', '2', '7', 'Covid_19', 'VaccinezVous']
# ['Nüremberg', 'Dégoulinant', 'Nazisme', 'Alors', 'FÜHRERPRINZIP', 'Propagande', 'GOEBBELS', 'Mengele', 'ARBEIT', 'MACHT', 'FREI', 'commué', 'VAX', 'PASS', 'MACHT', 'FREI', '1', '3', 'FÜHRERPRINZIP', 'Propagande', 'GOEBBELS', 'Mengele']
# ['Perronne', 'Si', 'rael', '10160144001754345', '0', 'AZXTFnps', 'u0fJfhH8Qxjs2aalBG7POKdaL0eXDhDMlJpnh5dDP4oFWV679kD0T557ZxhV5b2MHVakS0g6pReSUVatwsdpN47dvuEy5E', '3Lv5aOyX8gu0pwqwFtbi', 'd05jJY', '2CO', '2CP', 'R…', 'Pandemie', 'omicrom', 'Sante', '3', '4', 'Perronne', 'Pandemie', 'omicrom', 'Sante']
# ['Recensement', 'EffetsSecondaires', 'Vaccins', 'effetsecondaires', 'effetsindesirables', 'EFFETSECONDAIRE', 'covid', 'Accueil', 'covid', '3', '3', 'EffetsSecondaires', 'Vaccins.', 'effetsecondaires', 'effetsindesirables', 'EFFETSECONDAIRE']
# ['COVID19', 'PassSanitaire', 'PassVaccinal', '1', '2', 'COVID19>', 'PassSanitaire>', 'PassVaccinal>']
# ['RT', 'BFMTV', 'Jean', 'Luc', 'Mélenchon', 'From', 'BFMTV', '2', '2', 'Mélenchon,', 'masques,', 'vaccins,']
# ['Europe', 'Pr', 'Claverie', '074172506', 'laborigins', '…', 'Attention', 'lattention', '3', 'Jan', '2', '2']
# ['Vaccins', '2', '2', 'Vaccins']
# ['Combien', 'VéranPinnochio', 'VeranEnPrison', 'MacronDestitution', 'mensongedetat', 'effetssecondaires', 'VaccinationObligatoire', 'Caroline', 'Var', 'CarolineVar1', '3', 'Jan', '19', 'P', '19', 'VéranPinnochio', 'VeranEnPrison', 'MacronDestitution', 'mensongedetat', 'effetssecondaires', 'VaccinationObligatoire']
# ['Pardon', 'olivierveran', 'Sauver', '3', '2021', '’', 'PassVaccinalDeLaHonte', 'CNEWS', 'CNEWS', '3', 'Jan', '1', '48', 'Olivier', 'Véran', '’', '’', 'Français', '’', '’', '2', 'PassVaccinalDeLaHonte']
# ['Car', '’', 'eétudes', '’', 'Fastoche', 'EffetsSecondaires', 'LongTerme', '“', '”', 'ARNm', '’', 'Nathan', 'Peiffer', 'Smadja', 'nathanpsmad', '2', 'Jan', 'Super', 'TheFrenchVirol', '’', 'COVID', '19', 'Spoiler', '’', '’', '’', '1', '1', 'EffetsSecondaires', 'LongTerme']
# ['Bogdanoff', '6', 'inquisteur', 'IgorBogdanoff', 'GrichkaBogdanoff', 'COVID19', '2', '3', 'Bogdanoff,', 'frère,', 'IgorBogdanoff', 'GrichkaBogdanoff', 'COVID19']
# ['Données', 'DREES', '2021', 'Vaccinés', '65', '3', '54', '3', '59', '2', 'Covid19', 'PassSanitaire', 'Vaccins', 'OMS', 'DREES', '1', 'Covid19', 'PassSanitaire', 'Vaccins', 'OMS', 'DREES']
# ['DirectAN', 'Débat', 'PasseVaccinal', 'Passesanitaire', 'COVID19', 'meurrent', '63', '1', 'DirectAN', 'PasseVaccinal', 'Passesanitaire', 'COVID19']
# ['Covid', '19', '8', 'Covid', '19', '18', 'dailyexpose', '2021', '08', '21', 'covid', '19', '8', 'covid', '19', '18', '…']
# ['VaccinationObligatoire', 'vaccination2022', 'Vaccin', 'ObligationVaccinale', 'PassVaccinal', 'PasseVaccinal', 'PasseSanitaire', 'PassSanitaire', 'PassSanitaires', 'passedelahonte', 'Covid', '19', 'NaphtalineLeBon', '24', 'Aug', '2021', 'Plus', 'Show', '1', 'VaccinationObligatoire', 'vaccination2022', 'Vaccin', 'ObligationVaccinale', 'PassVaccinal', 'PasseVaccinal', 'PasseSanitaire', 'PassSanitaire', 'PassSanitaires', 'passedelahonte', 'Covid_19']
# ['Promouvoir', 'Science', 'Triste', 'Covid19', 'Agence', 'France', 'Presse', 'afpfr', '3', 'Jan', 'Mort', '72', 'Igor', 'Bogdanoff', 'Grichka', 'AFP', 'Show', '1', 'Covid19', 'AFP']
# ['JLMelenchon', 'Courage', 'Vaccins', '3', '5', 'Vaccins']
# ['RT', 'BFMTV', 'Jean', 'Luc', 'Mélenchon', 'From', 'BFMTV', 'Mélenchon,', 'masques,', 'vaccins,']
# ['4', 'Covid', 'Questions', 'Obs', 'lobs', '3', 'Jan', 'Israël', '4e', '60', 'covid', '19', '20220103', 'OBS52807', '4e', '60', 'Autofeed', 'Social', 'Twitter', 'Echobox', '1641206578…', '1']
# ['7', 'Europe', 'DIVIZIO1', '1']
# ['Ben', 'covid', 'TouchezPasAuxEnfants', 'UnionSacree', 'PasseVaccinal', 'lefigaro', 'Covid', '19', '100', 'Face', '3', '1', 'covid', 'TouchezPasAuxEnfants', 'UnionSacree', 'PasseVaccinal']
# ['Covid', '19', 'démené', 'Alors', 'Payer', 'FAUX', 'PASSE', '’', '’', '’', '1', '1', 'Covid_19', 'PASSE']
# ['Gros', 'Business', 'Oui', '’', 'business…', '’', 'businessbourse', 'Gros', 'Business', 'Oui', 'Gros', 'Business', 'Oui']
# ['Bandes', 'VaccinationObligatoire', 'VaccinezvousBordel', 'odysee', 'Covid', '17', 'Covid', 'Lorsque', '3', 'LIVE', 'VaccinationObligatoire', 'VaccinezvousBordel']
# ['COVID', '’', 'covid', 'defaillance', 'dorganes', '…', 'COVID']
# ['COVID19', 'BREAKING', 'ALERTE', 'Faits', 'Vs', 'Déni', 'Infox', 'Criminelle', 'GBD', 'Vivre', 'OMS', 'Alerte', 'TOTALEMENT', 'RÉSISTANTS', 'Pandémie', 'CNBC', 'CQFD', 'Poke', 'Veran', 'Infox', 'MSM', 'WHO', 'warns', 'Covid', 'pandemic', 'drags', 'Reactionary', 'fostered', 'inequity', 'WHO', '1', 'COVID19[BREAKING-ALERTE]', 'Veran']
# ['Où', 'Ceux', 'Science', 'ECiotti', 'Gkats', 'GozGkats', '3', 'Jan', 'Fils2Psy', 'statu…', '1', '1', 'omicron.']
# ['DIVIZIO1', 'Pensons', 'Culture', 'veroniquegenest', 'Castex19h', 'COVID19', 'Pandemie', 'Omicron', 'Vaccin', 'Steiner', 'Steiner61421320', '3', 'Jan', 'Merci', 'veroniquegenest', 'Manif3Janvier', 'NonAuPassVaccinal', 'AssembleeNationale', '2', 'Castex19h.', 'COVID19', 'Pandemie', 'Omicron', 'Vaccin', 'Manif3Janvier', 'NonAuPassVaccinal', 'AssembleeNationale']
# ['34', '’', 'AstraZeneca', 'France', '27', 'COVAX', 'Solidarity', 'francetvinfo', 'AstraZeneca', '2021', 'AstraZeneca', '’', 'France', '’', 'Enquête', 'COVAX,']
# ['Grosse', 'Bougeons', 'covid19', 'mediazone', 'zonefr', 'Alerte', 'Document', 'URGENT', 'SÉCURITÉ', 'FRANÇAIS', 'Document', 'Mairies', '4', '1', 'covid19']
# ['RT', 'BFMTV', 'Jean', 'Luc', 'Mélenchon', 'From', 'BFMTV', 'Mélenchon,', 'masques,', 'vaccins,']
# ['ThaLieNaAckerm1', 'TOUT', 'EffetsSecondaires', 'covid', 'AssoCovid', 'covid', 'Accueil', 'covid', '2', '2', 'EffetsSecondaires']
# ['RemiSalomon', 'Quand', '’', '’', 'A', '’', '’', 'ARNm', '1', 'ARNm.']
# ['Avoir', '’', 'oliviermarleix', '’', '’', 'Veuillez', 'lemediaen442', 'vaccinologue', 'Geert', 'Vanden', 'Bossche', 'Geert', 'Vanden', 'Bossche', '1']
# ['SOSmédecins', 'SAMU', 'doctolib', '1', 'SOSmédecins', 'SAMU']
# ['CNEWS', 'morandinilive', 'Cohen', 'dtpolio', '20', 'Covid', 'Renvoyez', '4', 'morandinilive', 'Cohen', 'dtpolio', 'Covid']
# ['Mediavenir', 'Pfizer', 'babosse', '2', '6', 'Pfizer']
# ['Thread1', '3', 'Urgence', 'Vaccins', 'ARNm2️⃣', 'Pfizer', 'Macron', 'Buzyn', 'Veran', 'P4', 'Justice', 'Coronavirus', 'CourPenaleInt', 'INTERPOL', 'HQ', 'WallstreetJNews', 'CourUEPresse', 'boujemaâProc', '6456GJ', 'boujemaa', '3', 'Jan', 'Justice', 'Covid19', '’', '2023', 'Myocardites', 'Leucopathies', 'cécités', 'elcartagenese', '…', 'Vaccins', 'ARNm2️⃣', 'Pfizer', 'Macron(&', 'Veran..)', 'P4..Justice', 'Coronavirus', 'Covid19:mensonges', 'Myocardites', 'Leucopathies', 'cécités', 'surdités..']
# ['JLMelenchon', 'AN', 'PassVaccinal', 'COVID19', '’', 'Pfizer', '’', 'Melenchon', 'Fichue', '1', 'AN', 'PassVaccinal', 'COVID19', 'Pfizer', 'Melenchon']
# ['2', 'JEAN', 'JACQUES', 'CRÈVECOEUR', 'influenceur', 'complotiste', 'AstraZeneca', 'Pfizer', 'Moderna', '’', '’', 'antivaxx', '1', 'complotiste', 'Pfizer']
# ['Gocentrique', 'AdinaDSC', 'BillGates', 'DÉJÀ', 'Combien', 'BigPharma', '1', '1', 'BillGates', 'BigPharma']
# ['franceinter', 'olivierveran', '2', 'Covid', '19', 'Vidéo', '42', 'odysee', 'CSI', 'n°34', '2', '2021', 'Pierre', 'Chaillot', 'hospitali', 'View', 'CSI', 'n°34', '2', '2021', 'Pierre', 'Chaillot', '2020', 'Odysee', '1', 'Covid_19']
# ['CNEWS', 'morandinilive', 'Cohen', '3', 'morandinilive', 'Cohen', 'vaccins,']
# ['Didier', 'Raoult', '“', 'DG', '’', '’', '’', '”', 'PassVaccinal', 'Covid', '19', '0', '59', '9', '980', '8', '146', '287', 'PassVaccinal', 'Covid_19']
# ['BBC', 'EffetsSecondaires', 'Lesinfirmieres1', '3', '67', '58', 'BBC', 'EffetsSecondaires']
# ['Pompiers', 'Samu', 'Pharmaciens', 'Médecins', 'Infirmiers', 'Ambulanciers', 'Vaccins', 'Thrombose', 'Pericardite', 'Myocardite', 'Avc', 'Après', 'Résistance', '2', '13', '18', 'Pompiers', 'Samu', 'Pharmaciens', 'Médecins', 'Infirmiers', 'Ambulanciers', 'Vaccins', 'Thrombose', 'Pericardite', 'Myocardite', 'Avc', 'Résistance']
# ['Prochaine', 'VaccinationObligatoire', 'Emmerder', 'immunite', 'Covid', 'Macron', 'AFP', 'COVID19', 'Agence', 'France', 'Presse', 'afpfr', '4', 'Jan', 'Emmanuel', 'Macron', '’', 'Parisien', 'AFP', '3', '26', '33', 'VaccinationObligatoire', 'immunite', 'Covid', 'Macron', 'AFP', 'COVID19', 'AFP']
# ['BFMTV', 'E', 'Macron', '1', '2', 'sécures', '3', 'Français', '3', '39', '108']
# ['Dr', 'Peter', 'McCullough', '2021', 'Déces', 'Vaccins', 'COVID19', 'EffetsSecondaires', 'EffetsIndesirables', 'Peter', 'McCullough', 'MD', 'MPH', 'P', 'McCulloughMD', '1', 'Jan', 'Good', 'Medscape', 'tepidly', 'reluctant', 'Cumulative', 'understates', 'CDC', 'FDA', 'NIH', 'nonfatal', 'happened', '4', '5', 'COVID19', 'EffetsSecondaires', 'EffetsIndesirables']
# ['Quand', 'BigPharma', 'France', 'Parce', 'Pfizer', 'Moderna', '5', '7', 'BigPharma', 'Pfizer', 'Moderna']
# ['Variants', 'nonvaccinés', 'Variants', '2', '5', 'Variants', 'nonvaccinés,', 'Variants']
# ['Covid', '19', 'Variant', 'FrenchVariant', 'Quand', 'LevéeDesBrevets', 'Vite', 'lindependant', 'Covid', 'France', '12', 'Sars', 'Cov', '2', 'France', 'B', '1', '640', '2', '’', 'OMS', 'i24News', '1', '4', '8', 'Covid_19', 'Variant', 'FrenchVariant', 'LevéeDesBrevets']
# ['URGENT', 'BOOM', 'SÉQUENCE', 'HALLUCINANTE', 'BFMTV', 'CET', 'APRÈS', 'MIDI', 'DR', 'STEPHANE', 'GAYET', 'HÔPITAUX', 'STRASBOURG', 'BALANCE', 'TOUTE', 'VÉRITÉ', 'VACCINS', 'VARIANTS', 'VARIANTS', 'RÉSULTAT', 'VACCINATION', 'Laurent', 'Mcse', 'VK', 'Laurent', 'Mcse', 'URGENT', 'BOOM', 'SÉQUENCE', 'HALLUCINANTE', 'BFMTV', 'CET', 'APRÈS', 'MIDI', 'DR', 'STEPHANE', 'GAYET', 'HÔPITAUX', 'STRASBOURG', 'BALANCE', 'TOUTE', 'VÉRITÉ', 'VACCINS', 'VARIANTS', 'VARIANTS', '1', '8', '8', 'VACCINS', 'VARIANTS']
# ['TOUS', 'VACCINÉS', 'TOUS', 'CONTAMINÉS', 'Conseil', 'COVID19', 'Tous', 'Mensonges', 'PassSanitaire', 'Vaccins', 'COVID19', 'PassSanitaire', 'Vaccins']
# ['Merci', 'Pr', 'Elie', 'Giorno', 'Elie', 'Giorno', '4', 'Jan', 'PR', 'Raoult', 'Euro', 'Américains', 'Arn', 'Adn', 'PassVaccinalDeLaHonte', '8', '9', 'Raoult', 'PassVaccinalDeLaHonte']
# ['VIH', 'SARSCoV2', 'ARN', 'reponseimmunitaire', 'Virus', 'Immunity', 'vaincrelamuco', 'Sidaction', 'Sidaction', '4', 'Jan', 'Replay', 'VIH', '’', 'Explications', 'Olivier', 'Schwartz', '’', 'institutpasteur', 'Anne', 'Geneviève', 'Marcelin', 'HopPitieSalpe', '2', '12', 'VIH', 'SARSCoV2', 'ARN', 'reponseimmunitaire', 'VIH']
# ['Quand', 'COVID19', 'PasseSanitaire', 'Certains', '1', 'PasseSanitaire']
# ['KAMOULOX', 'BFM', 'COVID19', 'Omicron', 'COVID19France', 'COVID19fr', 'JeNeMeVaccineraiPas', 'VaccinationObligatoire', 'France', 'Macron', 'PasseVaccinal', 'PasseSanitaire', 'CouvreFeu', 'BFM', 'COVID19', 'Omicron', 'COVID19France', 'COVID19fr', 'JeNeMeVaccineraiPas', 'VaccinationObligatoire', 'France', 'Macron', 'PasseVaccinal', 'PasseSanitaire', 'CouvreFeu']
# ['3emeDose', 'Omicron', 'VaccinezvousBordel', 'VaccinezVous', 'Vaccin', 'Omicron', 'NonAuPassVaccinal', 'NonALaVaccinationObligatoire', 'NonAuVaccinObligatoire', 'LouisVuitton', 'Duval', 'Philippe', '4', 'Jan', '1', '1', '000', '000', '000€', '1', '3emeDose', 'Omicron', 'VaccinezvousBordel', 'VaccinezVous', 'Vaccin', 'Omicron', 'NonAuPassVaccinal', 'NonALaVaccinationObligatoire', 'NonAuVaccinObligatoire', 'LouisVuitton']
# ['Covid19', 'GBMV', 'SECURITE', '3°', 'Tous', 'acnancymetz', 'HuartJean', 'AnnickPastwa', 'voiepro', 'voiepro']
# ['Pfizer', 'mascaradeSanitaire', 'creditSocial', 'NonAuPassVaccinal', 'Yeadon', 'Pfizer', 'Dr', 'Michael', 'Yeadon', 'Pfizer', '32', '’', '1', '2', 'mascaradeSanitaire', 'creditSocial', 'NonAuPassVaccinal', 'Yeadon']
# ['PasseVaccinal', 'PassVacinal', 'FLASH', 'INFO', 'Gravissime', 'MASSIVEMENT', 'FrammeryChloe', 'ArthusBrega', 'JuniorGuibole', 'cab2626', 'DIVIZIO1', 'PeterbobBaze', 'AgretDenis', 'CaudeHenrion', 'ChDEVILLERS', 'PdF', 'gkierzek', 'francemediasnumerique', '2022', '01', '04', 'vaccinees', 'developperont', 'dimmunodeficience', '2022', 'mailpoet', '4…', '1', '3', '4', 'PasseVaccinal', 'PassVacinal']
# ['’', 'taskforce', 'Celli', 'Tenez', 'Omicron', 'Jlz', 'jlz069', '3', 'Jan', '1', 'taskforce', 'Celli', 'Omicron']
# ['A', 'vaccinez', 'Omicron', 'VariantOmicron', 'VaccinationObligatoire', 'Vaccin', 'VaccinezVous', 'COVID19France', 'antivax', 'Veran', 'Côté', 'Science', 'Cote', 'Science', '4', 'Jan', 'Covid', '19', 'DoctoraEdith', 'jljcolorado', 'st…', 'Omicron', 'VariantOmicron', 'VaccinationObligatoire', 'Vaccin', 'VaccinezVous', 'COVID19France', 'antivax', 'Veran']
# ['rglucks1', 'WeillClaude', '338', 'Kremlin', 'Voilà', 'Intox', 'The', 'potentially', 'Change', 'View', '2', '4', 'Kremlin']
# ['FFP2', 'PasseVaccinal', 'GIF', 'ALT', 'FFP2', 'PasseVaccinal']
# ['Réflexion', 'MLP', 'Assemblee', 'Veran', 'conseildedéfense', '’', 'PassVaccinal', 'Où', 'ARN', 'Patrick', 'Edery', 'edery', '4', 'Jan', 'MLP', 'Véran', 'Assembléeen', 'Français', 'Is', 'ARN', '1', 'MLP', 'Assemblee', 'Veran', 'conseildedéfense', 'PassVaccinal', 'MLP', 'Véran']
# ['Ô', 'Mamamouchi', 'JLMelenchon', 'Donnez', 'préférants', 'Envie', 'Jean', 'Luc', 'Mélenchon', 'JLMelenchon', '4', 'Jan', 'Président', 'OMS', 'Emmerder', 'Consternant', 'Macron', '1', '2', 'vaccins.', 'Macron']
# ['Ardèche', 'Fareva', '10', 'Apiject', 'Systems', '500', 'monodoses', '3JcWblO', '1', 'Ardèche', 'Fareva', 'vaccins.']
# ['COVID19France', 'hopitalpublic', 'Moins', 'instagram', 'Voix', 'Nord', 'lavoixdunord', '•', 'Instagram', 'COVID19France', 'hopitalpublic']
# ['Covid19', 'Coronavirus', 'Vaccins', 'France', 'Non', 'Karim', 'Covid', '19', 'Abdelkrim', 'Azzaoui', 'Karim', 'Covid', '19', '20', '2021', '’', 'AFP', '1', '3', '2', 'Covid19', 'Coronavirus', 'Vaccins', 'France']
# ['’', 'antivax', '2', '1', 'antivax', 'délire.']
# ['’', '’', 'ARNm', 'effetsSecondaires', 'covid19', 'reseauinternational', '’', '’', 'ARNm', 'Sucharit', 'Bhakdi', 'MD', 'Arne', 'Burkhardt', 'MD', 'Bhakdi', 'Burkhardt', 'Doctors', '2', '2', 'effetsSecondaires', 'covid19']
# ['Covid19', 'Veran', 'Omicron', 'Allemagne', 'Danemark', 'Islande', 'RoyaumeUni', 'France', 'businesstravel', 'Covid', '19', '’', 'ARNm', 'Covid19.', 'Veran', 'Omicron.', 'Allemagne,', 'Danemark,', 'Islande,', 'RoyaumeUni', 'France']
# ['Richard', 'Ferrand', 'Assemblée', 'Covid', '19', 'RT', 'France', '94297', 'covid', '19', 'fbclid', 'IwAR34F6E6w3', 'BbVoVcd2kL5Ef4FOHeBzQSvhbOM0UHgE0VAiQ8W3deBbF', 'X4…', 'Covid19', 'PassSanitaire', 'Médicaments', 'Vaccins', 'OMS', 'Rien', 'Politique', 'Assemblée', 'Economies', 'Covid19', 'PassSanitaire', 'Médicaments', 'Vaccins', 'OMS', 'Politique', 'Assemblée', 'Economies']
# ['Bé', 'JLMelenchon', 'JLMelenchon', 'JLM', 'youesse', 'fauxculisme', 'Libération', '4', 'Jan', 'Faut', '45', '’', 'Mélenchon', 'CheckNews', 'checknews', '45', 'laffirme', '20220104', 'OGY3UJ7EVNFNRNLPCYW2HWQJ5M', 'Social', 'xtor', 'CS7', '51', 'Twitter', 'Echobox', '1641297018', '1…', '1', 'fauxculisme', 'CheckNews']
# ['immunitécollective', 'Vaccins', 'Vaccins']
# ['olivierveran', 'Pfizer', 'Moderna', 'EffetsSecondaires', 'myocardite', 'Veran', 'Pfizer', 'Moderna', 'EffetsSecondaires', 'myocardite', 'Veran']
# ['nicolasberrod', 'Parisien', 'Pourquoi', '6', 'nonvaccines', 'génerait', 'effetsindesirables', 'EffetsSecondaires', 'impressionnez', '1', '3', '3', 'nonvaccines', 'effetsindesirables', 'EffetsSecondaires']
# ['LeFlurona', 'Infecté', 'Covid19', 'Flurona', 'Israël', 'ladepeche', '2022', '01', '03', 'covid', '19', 'flurona', '10024464', 'php…', 'ladepechedumidi', 'ladepeche', 'Infecté', 'Covid', '19', 'Flurona', 'Flurona', 'Covid', '19', 'Israël', 'LeFlurona', 'Covid19']
# ['covid', '’', 'PaulLarrouturou', '1', '5', 'covid', 'vaccins,']
# ['18', '07', '0', '19', '0', '0013', 'COVID', 'Vaccins', 'Omicron', 'Vaccins', 'Omicron', 'Bulletin', 'IHU', 'Pr', 'Didier', 'Raoult', 'Directeur', 'IHU', 'Méditerranée', 'Infection', 'COVID', 'Vaccins', 'Omicron']
# ['LCP', 'Avis', 'DirectAN', '4', 'Pourquoi', '3', '’', 'Non', 'Dis', 'Donc', 'Non', 'MaisDisDonc', '2', 'Nov', '2021', 'Pourquoi', '3', 'Car', '15', '’', '3', '1', '2', 'Donc', 'poir', 'ihu', 'Show', '2', '16', '1', '835', '1', 'DirectAN,', 'ihu']
# ['Voici', '’', 'Covid19', 'Coronavirus', 'Pass', 'Vaccins', 'France', 'Normandie', 'Covid', '19', '’', '’', '15', '2', '1', 'Covid19', 'Coronavirus', 'Pass', 'Vaccins', 'France', 'Normandie']
# ['JustinTrudeau', 'Calgary', 'Trouvez', 'cornavirus', 'goog', 'covid19', 'covid', '19', 'outreach', 'US…', '1', 'cornavirus']
# ['Après', '’', 'UE', '’', 'Union', '’', '’', 'benfox83', '2022', '’', 'UE', 'Afrique', 'Près', 'Commission', '’', 'Afrique', '’', 'UE', '’', 'Union', '1']
# ['lemondefr', '’', '2019', 'raisonsdagir', '…', 'bigmedia', 'bigpharma', 'bigmedia', 'bigpharma...']
# ['AssembleeNat', 'AssembleeNationale', 'Senat', 'minautore', 'QRCodes', 'Moderna', 'Pfizer', 'AstraZeneca', 'Macron20h', 'Delfraissy', '20', 'Minutes', '20Minutes', '1', 'Nov', '2018', 'Toulouse', 'Cinq', 'Minotaure', '2qjUV9d', 'AssembleeNationale', 'minautore', 'QRCodes', 'Moderna/#Pfizer/#AstraZeneca', 'Macron20h/#Delfraissy']
# ['MathieuSlama', 'MikeDub64', 'E', 'Macron', '1', '1']
# ['LCP', 'olivierveran', 'MartineWonner', 'secretdefense', 'conseildedefense', 'Bravo', 'MartineWonner', '2', '5', 'secretdefense', 'conseildedefense']
# ['GODAN1001', 'stephder2', 'AdeMontchalin', 'Ouais', 'Comme', 'PasseVaccinal', 'MacronistesFascistes', '2', 'PasseVaccinal', 'MacronistesFascistes']
# ['BetraMaurice', 'deyyanno', '4', 'Nüremberg', 'Dégoulinant', 'Nazisme', 'Alors', 'FÜHRERPRINZIP', 'Propagande', 'GOEBBELS', 'Mengele', 'ARBEIT', 'MACHT', 'FREI', 'commué', 'VAX', 'PASS', 'MACHT', 'FREI', '1', 'FÜHRERPRINZIP', 'Propagande', 'GOEBBELS', 'Mengele']
# ['Rien', 'E', 'Macron', 'Mathieu', 'Slama', 'MathieuSlama', '4', 'Jan', 'Emmanuel', 'Macron', '’', 'Suivi', '’', '’', 'Etat', '1']
# ['Non', 'VaccinObligatoire', 'Vaccination', 'Genocide', 'VaccinezVous', 'VaccinezvousBordel', 'NousSavons', 'Pfizer', 'PassVacinal', 'PasseVaccinalDeLaHonte', 'EffetsSecondaires', '4', '11', '24', 'VaccinObligatoire', 'Vaccination', 'Genocide', 'VaccinezVous', 'VaccinezvousBordel', 'NousSavons', 'Pfizer', 'PassVacinal', 'PasseVaccinalDeLaHonte', 'EffetsSecondaires']
# ['A', '’', 'Ensemble', 'COVID19', '22', '9', '59', 'COVID19']
# ['Danemark', 'Europe', '79', '99', '2nd', 'Aucune', 'Moun', 'Aber', 'Mounotella', '5', 'Jan', 'Veran', 'APHP', 'Vaccins', 'Malte', '99', '3', '48', '52', 'Danemark,', 'Veran', 'Vaccins', 'Malte,']
# ['Veran', 'APHP', 'Vaccins', 'Malte', '99', 'Vaccination', '8', '160', '171', 'Veran', 'Vaccins', 'Malte,', 'Vaccination']
# ['Vaccins', 'Iles', 'Féroé', '99', 'NonVaccinés', 'Macron', 'Moun', 'Aber', 'Mounotella', '5', 'Jan', 'Danemark', 'Europe', '79', '99', '2nd', 'Aucune', '7', '44', '51', 'Vaccins', 'NonVaccinés', 'Macron', 'Danemark,']
# ['Pr', 'Didier', 'Raoult', 'Omicron', 'Omicron', 'Delta', 'Vidéo', 'tvlibertes', 'Pr', 'Didier', 'Raoult', 'Omicron', 'Omicron', 'Delta', '6', '86', '183', 'Raoult', 'Omicron']
# ['Professeur', 'Didier', 'Raoult', '’', '’', '’', '…', 'NeTouchezPasAuxEnfants', 'StopVaccination', '4', '10', 'Raoult', 'vaccins.', 'NeTouchezPasAuxEnfants', 'StopVaccination']
# ['Après', 'outrageants', 'Macron', 'PassVacinal', 'PasseSanitaire', 'EffetsSecondaires', 'UnionSacree', 'AntiPassVaccinal', 'hdpros2', 'Raoult', 'nonvax', 'GIF', 'ALT', 'Macron', 'PassVacinal', 'PasseSanitaire', 'EffetsSecondaires', 'UnionSacree', 'AntiPassVaccinal', 'hdpros2', 'Raoult_didier', 'nonvax']
# ['Macron', 'NonVaccinés', 'Parisien', 'Vaccins', 'Covid', '10', '9', 'Macron', 'NonVaccinés', 'Vaccins', 'Covid']
# ['Si', 'MAINTENANT', '5emedose', 'Turquie', 'antivaxx', 'PassVaccinale', 'Covid19', 'nonvax', 'Omicron', 'Covid', 'VeranDemission', '4', '5emedose', 'Turquie', 'antivaxx', 'PassVaccinale', 'Covid19', 'nonvax', 'Omicron', 'Covid', 'VeranDemission']
# ['Bloqué', '’', 'Melbourne', 'covid19', 'The', 'potentially', 'Change', 'View', '2', '2', 'covid19']
# ['Vaccins', '1', '2', 'Vaccins']
# ['Non', 'Vaccination', 'Genocide', 'VaccinezVous', 'VaccinezvousBordel', 'Genocide', 'effetsindesirables', 'EffetsSecondaires', 'VaccinationObligatoire', 'PassVacinal', 'PasseVaccinalDeLaHonte', '2', '6', '19', 'Vaccination', 'Genocide', 'VaccinezVous', 'VaccinezvousBordel', 'Genocide', 'effetsindesirables', 'EffetsSecondaires', 'VaccinationObligatoire', 'PassVacinal', 'PasseVaccinalDeLaHonte']
# ['90', 'EmmanuelMacron', '3', '4', 'NonAuPassVaccinal', '1', '3', '3', 'NonAuPassVaccinal']
# ['HDPRO', '2', 'Covid', '19', '3emeDose', '15', 'PassSanitaire', '2', '2', '4', 'HDPRO', 'Covid_19', '3emeDose', 'PassSanitaire']
# ['Parce', '’', 'nonvaccines', 'Aude', 'Baron', 'AudeBaron', '4', 'Jan', '’', '’', 'journalistes…', 'Macron', '’', '’', '’', '1', '2', '8', 'nonvaccines']
# ['Forme', 'Pandémie', 'Saloper', 'overdoses', 'STOP', 'FOUTAGE', 'GUEULE', 'STOP', 'Tangosierra74', 'SierraTango74', '5', 'Jan', 'EmmanuelMacron', 'branquignols', 'GabrielAttal', '1', '2', 'Pandémie']
# ['Personne', 'levéedesbrevets', 'Covid', '19', 'COVID19', '1', '5', 'levéedesbrevets', 'Covid_19', 'COVID19']
# ['Surmortalité', 'Bien', 'nieront', 'Vaccins', 'stevekirsch', 'substack', 'unprecedented', 'deaths', 'for…', '1', '1', 'Surmortalité', 'Vaccins']
# ['Vaccins', 'Dangers', '3e', 'ARNm', 'Analyse', 'infodujour', 'Vaccins', '3ème', 'Deux', 'Dr', 'Jean', 'Marc', 'Sabatier', 'Pr', 'Jacques', 'Fantini', 'phénom', '1', '1', 'Vaccins']
# ['Covid', '19', 'MACRON', 'EMMERDE', 'URGENTISTES', 'COLERE', 'FNAC', 'GREVE', 'ACTU', 'PRÉSIDENTIELLE', 'APPROCHE', 'FINANCEZ', 'QG', 'CAMPAGNE', 'MÉDIA', 'TV', '2', '5', 'Covid_19']
# ['Ardèche', 'Fareva', '50', '€', 'Trois', 'monodoses', 'Annonay', 'Elles', '150', '3JcWblO', '2', '2', 'Ardèche', 'Fareva', 'vaccins.', 'Annonay.', 'emplois.']
# ['DeGoodenough', 'DocteurGonzo4', 'Macron', 'NonVaccinés', 'GiletsJaunes', 'Vaccins', 'Pesticides', 'malLogement', '’', 'France', 'cacatov', '1', 'Macron', 'NonVaccinés:', 'GiletsJaunes,', 'mutilés,victimes', 'Vaccins,#Pesticides,#malLogement,#democratie,', 'justice,', 'France.', 'cacatov']
# ['EmmanuelMacron', 'Omicron', 'Valneva', 'Bourse', 'DictatureSanitaire', 'PassVaccinal', 'Covid19', 'valneva', 'lindice', '120', '4', '2022', '1424414…', '1', '1', 'Valneva', 'Bourse.', 'DictatureSanitaire', 'PassVaccinal', 'Covid19']
# ['oxymetre', 'covid', '1', '3', '7', 'covid']
# ['A', 'Vaccins', 'côte…', 'lesechos', 'valneva', '1995893', 'html…', '1', 'Vaccins']
# ['EffetsSecondaires', 'effetsindesirables', '’', '’', 'modifiées…', 'Tihana', 'TalonTihana', '5', 'Jan', 'CNEWS', 'Pourquoi', 'Tous', '93', 'ZERO', 'GabrielAttal', '2', 'EffetsSecondaires', 'effetsindesirables,']
# ['LCP', 'olivierveran', '64', 'réas', 'covid', 'immuniténaturelle', 'réas', 'mimiryudo', 'Ecole', 'Oubliee', '5', '17', 'réas', 'vaccins?', 'immuniténaturelle']
# ['’', 'Afrique', '’', '’', 'Covid', 'Afrique', 'Depuis', '2', '6', '9']
# ['MinkaOceane', 'Dr', 'Nan', 'Quand', 'Comme', 'vaxx', 'Allez', '2', '4', '9', 'vaccins,']
# ['Scandale', 'Dépakine', 'Sanofi', '’', '’', 'Vaccins', 'Médicaments', 'Santé', 'OuestFrance', 'Scandale', 'Dépakine', 'Sanofi', '’', '’', '’', 'France', 'Sanofi', '’', '2', '3', 'Dépakine', 'Sanofi', 'Vaccins,', 'Médicaments', 'Santé']
# ['Pr', 'Didier', 'Raoult', 'Omicron', 'Omicron', 'Delta', 'Vidéo', 'tvlibertes', 'intelligents…', 'gettr', 'pmc2qc31d6', 'tvlibertes', 'Pr', 'Didier', 'Raoult', 'Omicron', 'Omicron', 'Delta', '2', 'Raoult', 'Omicron']
# ['Leclerc', 'COVID19', 'autotest', 'GIF', 'ALT', 'Lberty9L', 'Jesuispascon10', '4', 'Jan', 'Eh', '1', 'COVID19', 'autotest']
# ['1', 'presidentdelaRepublique', 'nonvaccinés', 'EmmanuelMacron', '1', '1', '3', '3', 'presidentdelaRepublique', 'nonvaccinés",']
# ['Donc', 'FDO', 'Vaccins', 'Monsieur', 'EmmanuelMacron', 'emmerdés', '1', '1', '4', 'FDO', 'Vaccins,']
# ...
# ['Deux', 'Chine', 'ARNm', '3xe1iil', '1', 'Chine']
# ['18', '000', 'France', '140', '000', 'France']
# ['Amore', 'Miiio']
# ['Décharges', 'Parsonage', 'Turner', 'Pfizer', 'Midilibre', '3NT6ca8', 'Pfizer', '1', '1', 'Pfizer']
# ['RATS', 'LABO', 'REMERCIENT', 'MACRON', 'AVOIR', 'PROTEGES', '’', 'OPECST', 'Vaccins', 'Vaccination', 'COVID19', 'pgibertie', 'RATS', 'LABO', 'REMERCIENT', 'MACRON', 'AVOIR', 'PROTEGES', '’', '2020', '’', '’', '’', '’', '…', '1', 'MACRON', 'OPECST', 'Vaccins', 'Vaccination', 'COVID19']
# ['7', 'Thread', '60', 'Français·es', 'Vaccins', 'Baromètre', 'presidentielles2022', 'focus2030', 'Barometre', 'Presidentielle', '2022', 'enjeux…', 'FairePlusPourlaSantéMondiale', '3', 'Thread', 'Vaccins', 'Baromètre', 'presidentielles2022', 'FairePlusPourlaSantéMondiale']
# ['FAUTE', 'PRÉVENIR', 'DEPUIS', 'MARS', '2020', 'EffetsSecondaires', 'COVID19', 'endothelium', 'myocardites', 'nonvaccines', '0dose', 'MacronDehors', 'Reconquete', 'ZemmourPresident', 'JC', 'josycesarini', '6', 'Apr', 'Cela', 'EffetsSecondaires', 'COVID19', 'endothelium', 'myocardites', 'nonvaccines', '0dose', 'MacronDehors', 'Reconquete', 'ZemmourPresident']
# ['3', 'MACRON', 'HAIS', 'TOUTE', 'FORCES', 'MacronDehors', 'MacronDehorsAuPremierTour', 'COVID19', 'Presidentielles', 'MACRON', 'MacronDehors', 'MacronDehorsAuPremierTour', 'COVID19', 'Presidentielles']
# ['UE', '55', 'Covid', '7sur7', '55', 'covid', 'abb659df', 'whatsapp', 'socialsharing', 'web…', 'Covid']
# ['DAVIDDURY2', 'COVID19', 'bigpharma', '99', '95', '1', 'COVID19', 'bigpharma']
# ['Démocratie', '’', 'bashing', 'COVID', '19', 'Renalooo', 'Yvanie', 'Caillé', 'Yvanie', 'CailléFondatrice', '’', 'RenalooCaptation', 'Réinventer', 'démocratie', 'santé', 'Vendredi', '18', '2022', '14h', '18h30', 'SénatRetro', '1']
# ['Fabien', 'Roussel', '’']
# ['Coronavirus', 'Réunion', '65', 'LaReunion', '65', '103894…', 'LaReunion']
# ['FreeCollegeKids', 'Jul', 'Deschateaux', 'Pfizer', '1', 'Pfizer']
# ['manuelvalls', 'EmmanuelMacron', 'Quand', 'McKinseyMacronGate', 'AlstomGate', 'bataclan2015', 'McKinseyMacronGate', 'AlstomGate', 'bataclan2015']
# ['ivanrioufol', 'variantcambodgien', 'covid19', 'Sudafricain', '’', 'Directrice', 'institutpasteur', 'Écrivez', 'covid', '19', 'pasteur…', 'variantcambodgien', 'chinois.', 'covid19', 'Sudafricain', 'institutpasteur']
# ['Radio', 'Maximilien', 'Pourriture', 'Ursula', 'Leyen', 'Union', 'Européenne', 'UE', 'McKinsey', 'UrsulaVonDerLeyen', 'Macron', 'Confinement', 'Vaccins', 'Masque', 'Guerres', 'PaSSvaccinal', 'OTAN', 'Vaccination', 'Mensonge', 'presidentielles2022', 'Macronistan', 'UE', 'lemoteurderecherche', 'RADIO', 'MAXIMILIEN', 'Radio', 'Maximilien', '08', '04', '2022', 'Monsieur', 'Zemmour', 'Gauchiste', 'Mitterandien', 'Radio', 'UE', 'McKinsey', 'UrsulaVonDerLeyen', 'Macron', 'Confinement', 'Vaccins', 'Masque', 'Guerres', 'PaSSvaccinal', 'OTAN', 'Vaccination', 'Mensonge', 'presidentielles2022', 'Macronistan', 'UE']
# ['MAINTENANT', 'Allemagne', 'REJETTE', '1', '18', '31', 'Allemagne']
# ['MacronSiTuSavai', 'COVID', '14', '17', 'COVID']
# ['’', 'Vaccins', 'Chaque', '’', '’', 'EffetsSecondairesvaccins19', 'Mensonge', 'NouvelOrdreMondial', 'Pfizer', 'Moderna', 'Johnson', 'Collectif', 'Sauver', 'Science', 'GabinJean3', '7', 'Apr', 'Vaccins', 'covid', '20', 'Suite', 'covid', 'Elles', 'debraeul', 'debraeul', 'statu…', '1', '2', '5', 'Vaccins', 'EffetsSecondairesvaccins19', 'Mensonge', 'NouvelOrdreMondial', 'Pfizer', 'Moderna', 'Johnson']
# ['Pfizergate', 'EffetsSecondaires', 'Veran', 'Hamon', 'Senat', 'PassVaccinal', 'electionpresidentielle2022', 'Macron', 'Collectif', 'Sauver', 'Science', 'GabinJean3', '6', 'Apr', '1', '2', '13', '2', 'Maintenant', 'Show', '4', '4', 'EffetsSecondaires', 'Veran', 'Hamon', 'Senat', 'PassVaccinal', 'electionpresidentielle2022', 'Macron']
# ['covid19', 'EPIPHARE', 'ARN', 'myocardite', '12', '50', '12', '31', '2021', 'Myocardite', 'Covid', '19', 'Covid', '19', 'myocardite', '31', '2021', 'EPI', 'PHARE', '6', '24', '23', 'covid19']
# ['1', '20', 'Cela', 'EffetsSecondairesvaccins19', 'effetsindesirables', 'Doc', 'Anarchy', 'Substack', 'DoctorAnarchist', '7', 'Apr', 'Had', 'recurred', '1', 'She', 'Was', 'remission', '20', 'Seems', 'Show', '1', '4', 'EffetsSecondairesvaccins19', 'effetsindesirables']
# ['Golems', 'Frankenstein', 'Pfizer', 'Ben', 'Benjami77894159', '7', 'Apr', 'Vaccin', 'acouphenes', '’', 'Enfin', 'ledauphine', '2022', '04', '06', 'covid', '19', 'vaccins…', 'effetssecondaires', 'EffetsIndesirables', '3', '4', 'vaccins-poisons', 'Pfizer', 'acouphenes', 'effetssecondaires', 'EffetsIndesirables']
# ['USA', 'COVID19', 'USA', 'COVID19']
# ['Mat', 'Mute', '06', 'Gettr', 'MatMute', 'videogirl25', '7', 'Apr', 'Selon', '50', '60', 'COVID', '19', 'gov', '35350834', '1', '1']
# ['Covid', '’', 'effetsecondaires', 'Closer', 'closerfr', '7', 'Apr', 'Covid', '19', 'closermag', 'covid', '19', 'inquietantes', '1547159…', '1', '1', 'Covid', 'effetsecondaires']
# ['Veran', 'Pfizergate', 'electionspresidentielles2022', 'MacronTF1', 'Monde', 'lemondefr', '7', 'Apr', 'Covid', '19', 'Olivier', 'Véran', '’', '’', '60', '2022', '04', '07', 'covid', '19', '60', '6120977', '3244', 'Lehuit', 'Social', 'Twitter…', '1', '6', '8', 'Veran', 'Pfizergate', 'electionspresidentielles2022', 'MacronTF1']
# ['LREM', 'Échappée', 'Cours', '2e', 'Code', 'Nuremberg', 'Olivier', 'Véran', 'olivierveran', '7', 'Apr', '0', '43', 'covid', 'France', 'Grâce', 'Français', '1', '2', 'LREM']
# ['Oui', 'Maintenant', 'Montagnier', 'Nobel', '1', '5', '22', 'Montagnier,']
# ['vaccinsdu', 'Monde', 'SANOFI', 'PASTEUR', 'Docteur', 'StanleyPLOTKIN', 'Prêt', 'COVID19', 'Pfizergate', 'Pfizer', '2', '2', 'SANOFI', 'PASTEUR', 'StanleyPLOTKIN', 'COVID19', 'Pfizergate', 'Pfizer']
# ['Allez', '4e', 'TVA', 'stupidity', 'TVA', 'stupidity']
# ['TPMP', 'complotistes', 'Ça']
# ['hspitalisations', 'Rien', 'Alors', 'Salmonelles', 'Rappel', 'Kinder', 'Ferrero', 'France', 'Ferrero', 'Kinder', 'Surprise', 'Schoko', 'Bons', 'Europe']
# ['Tableau', 'Réinfo', 'Covid', 'Québec', '0', '2', 'reinfocovid', '4', '…', 'Vaccin', 'pfizersideeffects', '1', 'Vaccin', 'pfizersideeffects']
# ['Vaccins', 'Jean', 'Marc', 'Morandini', 'morandiniblog', '7', 'Apr', 'DERNIERE', 'MINUTE', 'Covid', '19', 'France', '’', '60', 'RTL', 'Olivier', 'Véran', 'jeanmarcmorandini', '495290', 'covid', '19', '60', 'html…', '1', 'Vaccins']
# ['dulac2', 'Madame', 'EI', 'VeranCharlatan', 'Pfizer', '1', '2', 'VeranCharlatan', 'Pfizer']
# ['Senegal', '’', 'Institut', 'PasteurDakar', 'Société', 'SFI', '3LijuuP', 'institutpasteur', 'OMS', 'Afrique', 'IFC', 'Banquemondiale', 'BM', 'Afrique', 'Afrique', 'Covid19', 'Economie', 'OMS', 'Sante', '6', '8', 'Senegal', 'vaccins.', 'Afrique', 'Covid19', 'Economie', 'OMS', 'Sante']
# ['VaccineSideEffects', 'VaccineDeaths', 'URGENCE', 'A', 'BRISER', 'OMERTA', 'Merci', 'joron', 'ArthusBrega', 'JuniorGuibole', 'Pilotte', 'DIVIZIO1', 'cab2626', 'DocteurPEB1', 'gkierzek', 'alainhoupert', 'longeot', 'Table', 'Invités', 'Melodie', 'Collectif', 'Où', 'Maître', 'Diane', 'ProtatDocteur', 'Kayser', '1', '3', 'VaccineSideEffects', 'VaccineDeaths']
# ['Covid', '’', 'SIDA', 'lecourrierdesstrateges', '2022', '03', '30', 'covid', 'deteriorent', 'dimmunodeficience', '…', 'cstrateges', 'lecourrierdesstrateges', 'Covid', '’', 'immunodéf', '2022', '’', 'Agence', 'système…', '1', '1', 'Covid']
# ['’', '’', '…', '–', '’', 'OMS', 'EffetsSecondairesvaccins19', 'Eloïse', 'Pfizer', 'businessbourse', 'OMS', 'OMS', 'Eloïse', 'Pfizer', '1', '1', 'EffetsSecondairesvaccins19', 'Pfizer,']
# ['RappelProduit', '€Pizza', 'Chocolats', 'Pfizer', '2021', 'Vaccination', 'COVID19', 'RappelProduit', 'Chocolats', 'Pfizer', 'COVID19']
# ['Pfizer', 'vonderleyen', 'Corruption', 'BFMTV', 'BFMTV', '7', 'Apr', 'Guerre', 'Ukraine', 'Ursula', 'Leyen', 'Kiev', 'leyen', 'indefectible', 'AD', '202204070611', 'html…', 'Pfizer', 'Corruption']
# ['Vaccins', 'thrombo', 'Dr', 'David', 'Smadja', 'HEGP', 'APHP', 'COVID19', '1', 'Vaccins', 'HEGP', 'COVID19']
# ['Exposé', '17h', 'Biologie', 'Vaccins', 'Comment', 'Existe', 'LesÉtincellesduPalais', 'Paris15', 'Lien', 'offerbooking', '5Boffer', '5D', '16', 'offerbooking', '5Bshow', '5D', '8733539', 'cHash', '780530f01b99625b421a2f3b95e530b3…', '1', 'Biologie', 'Vaccins', 'LesÉtincellesduPalais', 'Paris15']
# ['’', '’', 'OCDE', '’', 'Montagnier', 'Malone', '’', 'BHL', 'Jean', 'Robin', 'JeanRobinMedia', '7', 'Apr', 'Pourquoi', 'BHL', 'Chine', 'Ouïghours', 'Montagnier,', 'Malone...)internationaux.', 'BHL']
# ['Déclaration', 'UNESCO', 'Covid', '19', 'unesdoc', 'Déclaration', 'UNESCO', '1', 'Covid_19']
# ['3', 'Stefan', 'Lanka', '1', '1', 'vaccins,']
# ['Effets', 'COVID19', 'ladepeche', 'Covid', '19', 'Arythmie', '’', '32', 'Eloïse', 'Soave', 'polypathologie', 'Covid', '2021', 'Selon', '“', '”', '1', 'COVID19']
# ['lieudeurope', 'leurope', '2', '…', '’', '’', 'Covid', '19', 'VaccinesWork', 'santepublique', 'Covid-19', 'VaccinesWork', 'santepublique']
# ['Covid', '19', 'France', 'masantefacile', 'Covid', '19', 'France', 'France', 'Santé', 'Covid-19', 'vaccins:']
# ['Complotiste', 'Marie', 'Claire', 'EffetsSecondaires', 'effetsindesirables', 'Vaccin', 'Covid', '19', 'MacronDehorsDesLePremierTour', 'Macron', 'macron2022', 'LAS', 'LAS71609657', '7', 'Apr', 'Vaccin', 'Covid', '19', 'Marie', 'Claire', 'marieclaire', 'covid', '1425863', 'asp…', 'EffetsSecondaires', 'effetsindesirables', 'Vaccin', 'Covid_19', 'MacronDehorsDesLePremierTour', 'Macron', 'macron2022']
# ['JLM', 'soutien2022', 'DocteurGonzo4', 'Ça', 'ARN', '’', 'Nobel', 'ARN', 'Nobel']
# ['Tout', 'Covid', 'cdanslair', 'Cdanslair', 'Mediapart', 'VII', 'Xavier', 'Fin', '2022', 'Covid.', 'cdanslair', 'Mediapart']
# ['olivierveran', 'EmmanuelMacron', 'EffetsSecondairesvaccins19', 'Collectif', 'Sauver', 'Science', 'GabinJean3', '7', 'Apr', 'Vaccins', 'covid', '20', 'Suite', 'covid', 'Elles', 'debraeul', 'debraeul', 'statu…', 'EffetsSecondairesvaccins19']
# ['2', 'Car', '2', '2', 'MacronDehorsDesLePremierTour', 'Pfizer', 'McKinseyGate', 'RotschildGate', 'Corruption', 'MacronDehors', '1', 'MacronDehorsDesLePremierTour', 'Pfizer', 'McKinseyGate', 'RotschildGate', 'Corruption', 'MacronDehors']
# ['Covid', '19', 'Pandemie', 'Veran', 'EffetsSecondairesvaccins19', 'MacronAssassin', 'Pfizer', 'McKinseyMacronGate', '…', 'DimancheJeVoteMarine', 'DimancheMacronDegage', 'GIF', 'ALT', 'Mediavenir', 'Mediavenir', '7', 'Apr', 'FLASH', 'Olivier', 'Véran', '’', '4e', 'COVID19', '60', 'RTL', 'COVID19France', 'Covid_19', 'Pandemie', 'Veran', 'EffetsSecondairesvaccins19', 'MacronAssassin', 'Pfizer', 'McKinseyMacronGate', 'DimancheJeVoteMarine', 'DimancheMacronDegage', 'Véran', 'COVID19', 'COVID19France']
# ['Fraoui1983', 'McKinseyGate', 'McKinsey', 'McKinseyMacronGate', 'RothschildMacronGate', 'RothschildGate', 'Gemini', 'JeVousEmmerde', '…il', 'MacronDegage2022', 'GIF', 'ALT', '1', '1', 'McKinseyGate', 'McKinsey', 'McKinseyMacronGate', 'RothschildMacronGate', 'RothschildGate', 'Gemini', 'JeVousEmmerde', 'MacronDegage2022']
# ['3', 'Si', 'COVAX', 'gavi', '’', '’', '1', '1', '’', '’', '2', '7', '1', '1', 'COVAX', 'vaccins,']
# ['EmmanuelMacron', 'olivierveran', 'lâcherons', 'Jamais', 'Préparez', 'Justice', 'covid', 'EffetsSecondairesvaccins19', 'Cc', 'AssoCovid', 'DIVIZIO1', 'CLeguevaques31', 'Notelet13', 'UPGCS', 'Levcops', 'Florian', 'Philippot', '7', 'Apr', 'Enfin', 'Honnêtement', 'TPMP', 'Cyrilhanouna', 'Quasiment', 'tpmp', '15…', '1', '1', 'Justice', 'covid', 'EffetsSecondairesvaccins19', 'UPGCS', 'Levcops']
# ['Accès', '2', 'yodifiji', 'cavazzini', 'Trade', 'shada', 'youtu', 'a8R30iPZDe8', 'JournéeMondialedelaSanté', 'boellfrance', 'hbsRabat', 'boell', 'Accès', 'Covid', '19', 'Cependant', '1', '1', '2', 'pandémie"', 'JournéeMondialedelaSanté']
# ['Covid', '19', 'effetssecondaires', 'wikistrike', '2022', '04', 'covid', '19', 'html…', 'Santé', 'WikiStrikeW', 'wikistrike', 'Covid', '19', 'Wikistrike', 'Selon', 'Vaccine', 'Adverse', 'Event', 'Reporting', 'System', 'VAERS', '’', 'COVID', '19', 'Covid_19', 'effetssecondaires', 'Santé']
# ['Supérieurs', 'Lesinfirmieres1', 'Maz20974837', '346', '194', '197']
# ['Quand', 'complotistes', 'Maintenant', 'commplotiste', '1', '8', '21']
# ['Dr', 'R', 'Cole', 'Vaccins', 'Wuhan', 'Variants', '40', 'invalidités', '4', '4', 'Vaccins', 'Wuhan', 'Variants']
# ['Audition', 'EffetsSecondaires', 'Sénat', 'Diane', 'Protat', 'youtu', 'jlvaCI7Q4YU', 'Vaccination', 'COVID19', 'ouestmoncycle', 'ouestmoncycle', 'NavigantsLibres', '1', '28', '43', 'EffetsSecondaires', 'Sénat', 'Protat.', 'Vaccination', 'COVID19', 'ouestmoncycle']
# ['escr', 'NIER', 'Sûrs', 'Vaccinez', 'Mc', 'K', 'covid19France', 'effetssecondaires', 'France', '1', '1', 'covid19France', 'effetssecondaires', 'France']
# ['Inserm', 'agenceANRS', 'COVID19', '15', 'santépublique', 'covidlong', 'A', '3BHja3C', '4', '7', 'agenceANRS', 'COVID19', 'santépublique', 'covidlong']
# ['Efficacité', 'Vaccins', '’', 'OPECST', '’', 'Macron', 'Veran', 'Christine', 'Cotton', 'ChrisCottonStat', '7', 'Apr', 'ITW', '2', '75', '2020', 'Rapport', 'OPECST', '2020', '3', 'Vaccins', 'Macron', 'Veran']
# ['Non', 'FrenchPatriot', 'Jul', 'Taxi', '8', 'Apr', 'Dr', 'R', 'Cole', 'Vaccins', 'Wuhan', 'Variants', '40', 'invalidités', 'Vaccins', 'Wuhan', 'Variants']
# ['Télégramme', 'Vaccins', 'covid', 'Plus', 'covid', '19', '’', 'titrespresse', '59683572202', 'covid', 'covid', '19', 'massivesplus…', 'Vaccins']
# ['Table', 'Covid', 'businessbourse', 'Table', 'Covid', 'Table', 'Covid', 'Covid']
# ['Parce', 'protegent', 'COVID19', 'contagiosite', 'Agence', 'France', 'Presse', 'afpfr', '7', 'Apr', 'Covid', '19', '60', 'AFP', 'Show', '1', 'COVID19', 'contagiosite', 'AFP']
# ['Vaccins', 'TherapieGenique', 'Alzheimer', 'Parkinson', 'GilainBarre', 'COVID19', 'Alain', 'Houpert', 'alainhoupert', '8', 'Apr', '’', 'cnews', '2022', '04', '07', 'parsonage', 'vaccin…', 'Vaccins', 'TherapieGenique', 'Alzheimer', 'Parkinson', 'GilainBarre', 'COVID19']
# ['Robert', 'Kennedy', 'Jr', 'Children', '’', 'Health', 'Defence', 'covid', 'myocardites', 'businessbourse', 'Robert', 'Kennedy', 'Jr', 'Children', 'Health', 'Defence', 'Robert', 'Kennedy', 'Jr', 'Children', 'Health', 'Defence', 'covid', 'myocardites', 'Kennedy', 'covid']
# ['McKinsey', '’', '2076', 'Paul', 'distopiteur', '21', 'Feb', '16', '02', '2022', 'PARLEMENTAIRES', 'MENÉS', 'TERHES', 'EXIGENT', '1', 'DÉMISSION', 'IMMÉDIATE', 'URSULA', 'VON', 'DER', 'LEYEN', 'PRÉSIDENTE', 'COMMISSION', '2', 'SUPPRESSION', 'CERTIFICAT', 'COVID', 'NUMÉRIQUE', 'youtu', 'qhe20QRG', 'Rw', 'McKinsey', 'EU']
# ['Covid', 'Tribunal', 'Paris', 'assoc°', 'Bonsens', 'AIMSIB', 'Joseph', 'francesoir', 'dempoisonnement', 'deposee', 'paris…', 'bonsens', 'Association', 'BonSens', 'Préserver']
# ['Respect', 'effetssecondaires', 'covid', 'Où', 'ouestmoncycle', '4', 'Apr', 'Aujourd', '’', '’', 'ouestmoncycle', 'Show', 'effetssecondaires', 'covid']
# ['effetssecondaires', 'Pfizergate', 'COVID19', 'ChrisCottonStat', 'CNEWS', 'CNEWS', '7', 'Apr', 'Pfizer', '’', 'Parsonage', 'Turner', 'cnews', '2022', '04', '07', 'parsonage', 'vaccin…', 'effetssecondaires', 'Pfizergate', 'COVID19']
# ['Vaccins', '’', 'Tribunal', 'Paris', 'francesoir', 'Vaccins', '’', 'Tribunal', 'Paris', 'ENTRETIEN', 'X', '’', '1', 'Vaccins:']
# ['Senegal', 'Selon', 'AfricaCDC', '15', 'Africains', 'Covid', '19', '65', 'Afrique', '3LijuuP', 'PasteurDakar', 'OMS', 'Afrique', 'IFC', '1', 'Senegal', 'Covid_19,', 'Afrique.']
# ['Table', 'effetssecondaires', 'Covid', 'businessbourse', 'Table', 'Covid', 'Table', 'Covid', 'effetssecondaires', 'Covid']
# ['’', 'OMS', '’', 'antiCovid', 'The', 'potentially', 'Change', 'View']
# ['Momotchi', 'Raphaël', 'Berland', 'lemediaen442', 'Momotchi', 'Raphaël', 'Berland', 'Interviewé', 'Momotchi', 'Raphaël', 'Berland', 'Effets', 'vaccins"']
# ['GaveEmmanuelle', 'BFMTV', 'vonderleyen']
# ['XavierBazin2', 'Nuremberg2', 'Nuremberg2']
# ['Vaccins', '’', 'Tribunal', 'Paris', 'francesoir', 'dempoisonnement', 'deposee', 'paris…', 'The', 'potentially', 'Change', 'View', 'Vaccins:']

# %%
vaccins_traite = vaccins
vaccins_traite = vaccins_traite.assign(valeurs_vectorisation=valeurs_vectorisation)

vaccins_traite.to_csv("vaccinsTraitesFull.csv")

# %%
from pyspark.sql.types import StructType, StructField, IntegerType, StringType, ArrayType, TimestampType, FloatType

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("UserScreenName", StringType(), True),
    StructField("UserName", StringType(), True),
    StructField("Timestamp", TimestampType(), True),
    StructField("Text", StringType(), True),
    StructField("Embedded_text", StringType(), True),
    StructField("Emojis", StringType(), True),
    StructField("Comments", StringType(), True),
    StructField("Image link", ArrayType(StringType()), True),
    StructField("Tweet URL", StringType(), True),
    StructField("hashtags", ArrayType(StringType()), True),
    StructField("mot_cles", ArrayType(StringType()), True),
    StructField("valeurs_vectorisation", ArrayType(FloatType()), True)])

vaccins_spark = spark.read.csv('vaccinsTraitesFull.csv', inferSchema=True)
vaccins_spark.printSchema()
vaccins_spark.show()

# On ne peut pas utiliser PySpark a cause de problemes de compatibilité avec les array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [86], in <module>
#       1 from pyspark.sql.types import StructType, StructField, IntegerType, StringType, ArrayType, TimestampType, FloatType
#       3 schema = StructType([
#       4     StructField("id", IntegerType(), True),
#       5     StructField("UserScreenName", StringType(), True),
#    (...)
#      15     StructField("mot_cles", ArrayType(StringType()), True),
#      16     StructField("valeurs_vectorisation", ArrayType(FloatType()), True)])
# ---> 18 vaccins_spark = spark.read.csv('vaccinsTraitesFull.csv', inferSchema=True)
#      19 vaccins_spark.printSchema()
#      20 vaccins_spark.show()
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:1659, in DataFrame.__getattr__(self, name)
#    1649 """Returns the :class:`Column` denoted by ``name``.
#    1650
#    1651 .. versionadded:: 1.3.0
#    (...)
#    1656 [Row(age=2), Row(age=5)]
#    1657 """
#    1658 if name not in self.columns:
# -> 1659     raise AttributeError(
#    1660         "'%s' object has no attribute '%s'" % (self.__class__.__name__, name))
#    1661 jc = self._jdf.apply(name)
#    1662 return Column(jc)
#
# AttributeError: 'DataFrame' object has no attribute 'read'

# %%
vaccins_traite[['mot_cles','valeurs_vectorisation']][0:10]
# Out:
#                                             mot_cles  \
# 0  [vaccins, DictatureSanitaire, DictatureEnMarch...
# 1  [ère, bonne, résolution, cette, nouvelle, anné...
# 2  [pense, ⁦, NetflixFR, ⁩, CobraKai, raison, Mac...
# 3  [voeuxmacron, fake, fake, fake, news, Sans, ’,...
# 4  [petit, cadeau, tout, ceux, croient, vaccins, ...
# 5  [Annee2022, année, procès, gouvernementFR, Mac...
# 6  [Audition, Sénat, RatignierCarbonneil, directr...
# 7  [wargonm, quelle, après, cette, supposée, atti...
# 8  [ceux, détestent, NonVaccinés, disent, PasseVa...
# 9  [COVID19, corruption, arguments, favorables, v...
#
#                                valeurs_vectorisation
# 0  [-0.017874334007501602, -0.011175374500453472,...
# 1  [0.08690714836120605, 0.22452007234096527, 0.3...
# 2  [-0.20400500297546387, 0.18714751303195953, -0...
# 3  [-0.08908065408468246, -0.23232945799827576, 0...
# 4  [-0.033415451645851135, -0.2506740391254425, 0...
# 5  [0.006658188067376614, 0.4478951096534729, 0.0...
# 6  [0.23884639143943787, 0.046073608100414276, 0....
# 7  [-0.14385326206684113, 0.10333363711833954, 0....
# 8  [0.14957231283187866, 0.07924788445234299, -0....
# 9  [-0.036533914506435394, -0.015814892947673798,...
# ERROR! Session/line number was not unique in database. History logging moved to new session 12

# %%
# On utilise une autre librairie pour clusteriser avec KMEANS
from sklearn.cluster import KMeans

km = pd.DataFrame()
#les clusters
NUM_CLUSTERS=5
kmeans = KMeans(NUM_CLUSTERS, random_state=0)
km['cluster']=kmeans.fit_predict(vaccins_traite[['Unnamed: 0','valeurs_vectorisation']])

#les centroides
centroids = kmeans.cluster_centers_
cen_x = [i[0] for i in centroids] 
cen_y = [i[1] for i in centroids]
km['cen_x'] = df.cluster.map({0:cen_x[0], 1:cen_x[1], 2:cen_x[2], 3:cen_x[3], 4:cen_x[4]})
km['cen_y'] = df.cluster.map({0:cen_y[0], 1:cen_y[1], 2:cen_y[2], 3:cen_y[3], 4:cen_y[4]})
# define and map colors
colors = ['#DF2020', '#81DF20', '#2095DF', '#B0DB43', '#FFE4B5']
km['c'] = df.cluster.map({0:colors[0], 1:colors[1], 2:colors[2], 3:colors[3], 4:colors[4]})

# %%
import matplotlib.pyplot as plt
plt.scatter(vaccins_traite.index, vaccins_traite.valeurs_vectorisation, c=km.c, alpha = 0.6, s=10)
